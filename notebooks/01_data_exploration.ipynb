# %% [markdown]
# # Flight delays and weather condition – Data Exploration
#
# **Purpose**
# - Explore data for flight delays and weather condition use cases
# - Validate assumptions before adding API endpoints
# - Prototype logic for FastAPI services
#
# **Author:** Rashed
# **Date:** 2025-24-12

# %% [markdown]
# The `autoreload` feature of Jupyter ensures that if an imported module (.py file) changes, the notebook will automatically import the new version.
# (However, objects that were defined with the old version of the class won't change.)

# %%
# Executing this cell does some magic
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import requests
import pandas as pd

from dotenv import load_dotenv
import os

load_dotenv()


API_URL_Delay = "https://airlabs.co/api/v9/delays"
API_KEY = os.getenv("API_KEY")

airports = ["KJFK","KLAX","KORD","KDEN","KSFO","KSEA","KATL","KDFW","KMSP"]

params = {
    "api_key": API_KEY,
    "delay": 60,
    "type": "departures",
    "dep_icao": ",".join(airports),
    "max": 100,
}

API_URL = f"{API_URL_Delay}"

response = requests.get(API_URL, params=params)

data = response.json()
data
# Out:
# {'request': {'lang': 'en',
#   'currency': 'USD',
#   'time': 13,
#   'id': 'd839qysxweo',
#   'server': 'a',
#   'host': 'airlabs.co',
#   'pid': 2929279,
#   'key': {'id': 37729,
#    'api_key': '2f1914c4-fa35-4b93-9894-de62a5d49aa7',
#    'type': 'free',
#    'expired': '2026-01-25T00:00:00.000Z',
#    'registered': '2025-12-25T02:41:57.000Z',
#    'upgraded': None,
#    'limits_by_hour': 2500,
#    'limits_by_minute': 250,
#    'limits_by_month': 1000,
#    'limits_total': 998},
#   'params': {'delay': '60',
#    'type': 'departures',
#    'dep_icao': 'KJFK,KLAX,KORD,KDEN,KSFO,KSEA,KATL,KDFW,KMSP',
#    'max': '100',
#    'lang': 'en'},
#   'version': 9,
#   'method': 'delays',
#   'client': {'ip': '2607:fb91:4b0c:a7e3:352c:2adb:7af2:fa5d',
#    'geo': {'country_code': 'US',
#     'country': 'United States',
#     'continent': 'North America',
#     'lat': 37.751,
#     'lng': -97.822,
#     'timezone': 'America/Chicago'},
#    'connection': {},
#    'device': {},
#    'agent': {},
#    'karma': {'is_blocked': False,
#     'is_crawler': False,
#     'is_bot': False,
#     'is_friend': False,
#     'is_regular': True}},
#   'has_more': True,
#   'total_items': 241},
#  'response': [{'airline_iata': 'AM',
#    'airline_icao': 'AMX',
#    'flight_iata': 'AM4269',
#    'flight_icao': 'AMX4269',
#    'flight_number': '4269',
#    'dep_iata': 'MSP',
#    'dep_icao': 'KMSP',
#    'dep_terminal': '1',
#    'dep_gate': 'C10',
#    'dep_time': '2025-12-25 07:40',
#    'dep_time_utc': '2025-12-25 13:40',
#    'dep_estimated': '2025-12-25 09:07',
#    'dep_estimated_utc': '2025-12-25 15:07',
#    'dep_actual': '2025-12-25 09:07',
#    'dep_actual_utc': '2025-12-25 15:07',
#    'arr_iata': 'SLC',
#    'arr_icao': 'KSLC',
#    'arr_terminal': None,
#    'arr_gate': 'A39',
#    'arr_baggage': '8',
#    'arr_time': '2025-12-25 09:49',
#    'arr_time_utc': '2025-12-25 16:49',
#    'arr_estimated': '2025-12-25 11:03',
#    'arr_estimated_utc': '2025-12-25 18:03',
#    'cs_airline_iata': 'DL',
#    'cs_flight_number': '2628',
#    'cs_flight_iata': 'DL2628',
#    'status': 'active',
#    'duration': 189,
#    'delayed': 74,
#    'dep_delayed': 87,
#    'arr_delayed': 74,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766681340,
#    'dep_time_ts': 1766670000,
#    'arr_estimated_ts': 1766685780,
#    'dep_estimated_ts': 1766675220,
#    'dep_actual_ts': 1766675220},
#   {'airline_iata': 'KE',
#    'airline_icao': 'KAL',
#    'flight_iata': 'KE3269',
#    'flight_icao': 'KAL3269',
#    'flight_number': '3269',
#    'dep_iata': 'MSP',
#    'dep_icao': 'KMSP',
#    'dep_terminal': '1',
#    'dep_gate': 'C10',
#    'dep_time': '2025-12-25 07:40',
#    'dep_time_utc': '2025-12-25 13:40',
#    'dep_estimated': '2025-12-25 09:07',
#    'dep_estimated_utc': '2025-12-25 15:07',
#    'dep_actual': '2025-12-25 09:07',
#    'dep_actual_utc': '2025-12-25 15:07',
#    'arr_iata': 'SLC',
#    'arr_icao': 'KSLC',
#    'arr_terminal': None,
#    'arr_gate': 'A39',
#    'arr_baggage': '8',
#    'arr_time': '2025-12-25 09:49',
#    'arr_time_utc': '2025-12-25 16:49',
#    'arr_estimated': '2025-12-25 11:03',
#    'arr_estimated_utc': '2025-12-25 18:03',
#    'cs_airline_iata': 'DL',
#    'cs_flight_number': '2628',
#    'cs_flight_iata': 'DL2628',
#    'status': 'active',
#    'duration': 189,
#    'delayed': 74,
#    'dep_delayed': 87,
#    'arr_delayed': 74,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766681340,
#    'dep_time_ts': 1766670000,
#    'arr_estimated_ts': 1766685780,
#    'dep_estimated_ts': 1766675220,
#    'dep_actual_ts': 1766675220},
#   {'airline_iata': 'DL',
#    'airline_icao': 'DAL',
#    'flight_iata': 'DL2628',
#    'flight_icao': 'DAL2628',
#    'flight_number': '2628',
#    'dep_iata': 'MSP',
#    'dep_icao': 'KMSP',
#    'dep_terminal': '1',
#    'dep_gate': 'C10',
#    'dep_time': '2025-12-25 07:40',
#    'dep_time_utc': '2025-12-25 13:40',
#    'dep_estimated': '2025-12-25 09:07',
#    'dep_estimated_utc': '2025-12-25 15:07',
#    'dep_actual': '2025-12-25 09:07',
#    'dep_actual_utc': '2025-12-25 15:07',
#    'arr_iata': 'SLC',
#    'arr_icao': 'KSLC',
#    'arr_terminal': None,
#    'arr_gate': 'A39',
#    'arr_baggage': '8',
#    'arr_time': '2025-12-25 09:49',
#    'arr_time_utc': '2025-12-25 16:49',
#    'arr_estimated': '2025-12-25 11:03',
#    'arr_estimated_utc': '2025-12-25 18:03',
#    'cs_airline_iata': None,
#    'cs_flight_number': None,
#    'cs_flight_iata': None,
#    'status': 'active',
#    'duration': 189,
#    'delayed': 74,
#    'dep_delayed': 87,
#    'arr_delayed': 74,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766681340,
#    'dep_time_ts': 1766670000,
#    'arr_estimated_ts': 1766685780,
#    'dep_estimated_ts': 1766675220,
#    'dep_actual_ts': 1766675220},
#   {'airline_iata': 'LA',
#    'airline_icao': 'LAN',
#    'flight_iata': 'LA8958',
#    'flight_icao': 'LAN8958',
#    'flight_number': '8958',
#    'dep_iata': 'ATL',
#    'dep_icao': 'KATL',
#    'dep_terminal': 'S',
#    'dep_gate': 'B18',
#    'dep_time': '2025-12-24 21:35',
#    'dep_time_utc': '2025-12-25 02:35',
#    'dep_estimated': '2025-12-25 10:12',
#    'dep_estimated_utc': '2025-12-25 15:12',
#    'dep_actual': '2025-12-25 10:12',
#    'dep_actual_utc': '2025-12-25 15:12',
#    'arr_iata': 'PNS',
#    'arr_icao': 'KPNS',
#    'arr_terminal': None,
#    'arr_gate': '4',
#    'arr_baggage': None,
#    'arr_time': '2025-12-24 21:47',
#    'arr_time_utc': '2025-12-25 03:47',
#    'arr_estimated': '2025-12-25 10:25',
#    'arr_estimated_utc': '2025-12-25 16:25',
#    'arr_actual': '2025-12-25 10:25',
#    'arr_actual_utc': '2025-12-25 16:25',
#    'cs_airline_iata': 'DL',
#    'cs_flight_number': '1473',
#    'cs_flight_iata': 'DL1473',
#    'status': 'landed',
#    'duration': 72,
#    'delayed': 758,
#    'dep_delayed': 757,
#    'arr_delayed': 758,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766634420,
#    'dep_time_ts': 1766630100,
#    'arr_estimated_ts': 1766679900,
#    'dep_estimated_ts': 1766675520,
#    'arr_actual_ts': 1766679900,
#    'dep_actual_ts': 1766675520},
#   {'airline_iata': 'VS',
#    'airline_icao': 'VIR',
#    'flight_iata': 'VS1509',
#    'flight_icao': 'VIR1509',
#    'flight_number': '1509',
#    'dep_iata': 'ATL',
#    'dep_icao': 'KATL',
#    'dep_terminal': 'S',
#    'dep_gate': 'B18',
#    'dep_time': '2025-12-24 21:35',
#    'dep_time_utc': '2025-12-25 02:35',
#    'dep_estimated': '2025-12-25 10:12',
#    'dep_estimated_utc': '2025-12-25 15:12',
#    'dep_actual': '2025-12-25 10:12',
#    'dep_actual_utc': '2025-12-25 15:12',
#    'arr_iata': 'PNS',
#    'arr_icao': 'KPNS',
#    'arr_terminal': None,
#    'arr_gate': '4',
#    'arr_baggage': None,
#    'arr_time': '2025-12-24 21:47',
#    'arr_time_utc': '2025-12-25 03:47',
#    'arr_estimated': '2025-12-25 10:25',
#    'arr_estimated_utc': '2025-12-25 16:25',
#    'arr_actual': '2025-12-25 10:25',
#    'arr_actual_utc': '2025-12-25 16:25',
#    'cs_airline_iata': 'DL',
#    'cs_flight_number': '1473',
#    'cs_flight_iata': 'DL1473',
#    'status': 'landed',
#    'duration': 72,
#    'delayed': 758,
#    'dep_delayed': 757,
#    'arr_delayed': 758,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766634420,
#    'dep_time_ts': 1766630100,
#    'arr_estimated_ts': 1766679900,
#    'dep_estimated_ts': 1766675520,
#    'arr_actual_ts': 1766679900,
#    'dep_actual_ts': 1766675520},
#   {'airline_iata': 'AF',
#    'airline_icao': 'AFR',
#    'flight_iata': 'AF5614',
#    'flight_icao': 'AFR5614',
#    'flight_number': '5614',
#    'dep_iata': 'ATL',
#    'dep_icao': 'KATL',
#    'dep_terminal': 'S',
#    'dep_gate': 'B18',
#    'dep_time': '2025-12-24 21:35',
#    'dep_time_utc': '2025-12-25 02:35',
#    'dep_estimated': '2025-12-25 10:12',
#    'dep_estimated_utc': '2025-12-25 15:12',
#    'dep_actual': '2025-12-25 10:12',
#    'dep_actual_utc': '2025-12-25 15:12',
#    'arr_iata': 'PNS',
#    'arr_icao': 'KPNS',
#    'arr_terminal': None,
#    'arr_gate': '4',
#    'arr_baggage': None,
#    'arr_time': '2025-12-24 21:47',
#    'arr_time_utc': '2025-12-25 03:47',
#    'arr_estimated': '2025-12-25 10:25',
#    'arr_estimated_utc': '2025-12-25 16:25',
#    'arr_actual': '2025-12-25 10:25',
#    'arr_actual_utc': '2025-12-25 16:25',
#    'cs_airline_iata': 'DL',
#    'cs_flight_number': '1473',
#    'cs_flight_iata': 'DL1473',
#    'status': 'landed',
#    'duration': 72,
#    'delayed': 758,
#    'dep_delayed': 757,
#    'arr_delayed': 758,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766634420,
#    'dep_time_ts': 1766630100,
#    'arr_estimated_ts': 1766679900,
#    'dep_estimated_ts': 1766675520,
#    'arr_actual_ts': 1766679900,
#    'dep_actual_ts': 1766675520},
#   {'airline_iata': 'AM',
#    'airline_icao': 'AMX',
#    'flight_iata': 'AM4803',
#    'flight_icao': 'AMX4803',
#    'flight_number': '4803',
#    'dep_iata': 'ATL',
#    'dep_icao': 'KATL',
#    'dep_terminal': 'S',
#    'dep_gate': 'B18',
#    'dep_time': '2025-12-24 21:35',
#    'dep_time_utc': '2025-12-25 02:35',
#    'dep_estimated': '2025-12-25 10:12',
#    'dep_estimated_utc': '2025-12-25 15:12',
#    'dep_actual': '2025-12-25 10:12',
#    'dep_actual_utc': '2025-12-25 15:12',
#    'arr_iata': 'PNS',
#    'arr_icao': 'KPNS',
#    'arr_terminal': None,
#    'arr_gate': '4',
#    'arr_baggage': None,
#    'arr_time': '2025-12-24 21:47',
#    'arr_time_utc': '2025-12-25 03:47',
#    'arr_estimated': '2025-12-25 10:25',
#    'arr_estimated_utc': '2025-12-25 16:25',
#    'arr_actual': '2025-12-25 10:25',
#    'arr_actual_utc': '2025-12-25 16:25',
#    'cs_airline_iata': 'DL',
#    'cs_flight_number': '1473',
#    'cs_flight_iata': 'DL1473',
#    'status': 'landed',
#    'duration': 72,
#    'delayed': 758,
#    'dep_delayed': 757,
#    'arr_delayed': 758,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766634420,
#    'dep_time_ts': 1766630100,
#    'arr_estimated_ts': 1766679900,
#    'dep_estimated_ts': 1766675520,
#    'arr_actual_ts': 1766679900,
#    'dep_actual_ts': 1766675520},
#   {'airline_iata': 'KL',
#    'airline_icao': 'KLM',
#    'flight_iata': 'KL5172',
#    'flight_icao': 'KLM5172',
#    'flight_number': '5172',
#    'dep_iata': 'ATL',
#    'dep_icao': 'KATL',
#    'dep_terminal': 'S',
#    'dep_gate': 'B18',
#    'dep_time': '2025-12-24 21:35',
#    'dep_time_utc': '2025-12-25 02:35',
#    'dep_estimated': '2025-12-25 10:12',
#    'dep_estimated_utc': '2025-12-25 15:12',
#    'dep_actual': '2025-12-25 10:12',
#    'dep_actual_utc': '2025-12-25 15:12',
#    'arr_iata': 'PNS',
#    'arr_icao': 'KPNS',
#    'arr_terminal': None,
#    'arr_gate': '4',
#    'arr_baggage': None,
#    'arr_time': '2025-12-24 21:47',
#    'arr_time_utc': '2025-12-25 03:47',
#    'arr_estimated': '2025-12-25 10:25',
#    'arr_estimated_utc': '2025-12-25 16:25',
#    'arr_actual': '2025-12-25 10:25',
#    'arr_actual_utc': '2025-12-25 16:25',
#    'cs_airline_iata': 'DL',
#    'cs_flight_number': '1473',
#    'cs_flight_iata': 'DL1473',
#    'status': 'landed',
#    'duration': 72,
#    'delayed': 758,
#    'dep_delayed': 757,
#    'arr_delayed': 758,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766634420,
#    'dep_time_ts': 1766630100,
#    'arr_estimated_ts': 1766679900,
#    'dep_estimated_ts': 1766675520,
#    'arr_actual_ts': 1766679900,
#    'dep_actual_ts': 1766675520},
#   {'airline_iata': 'KE',
#    'airline_icao': 'KAL',
#    'flight_iata': 'KE7001',
#    'flight_icao': 'KAL7001',
#    'flight_number': '7001',
#    'dep_iata': 'ATL',
#    'dep_icao': 'KATL',
#    'dep_terminal': 'S',
#    'dep_gate': 'B18',
#    'dep_time': '2025-12-24 21:35',
#    'dep_time_utc': '2025-12-25 02:35',
#    'dep_estimated': '2025-12-25 10:12',
#    'dep_estimated_utc': '2025-12-25 15:12',
#    'dep_actual': '2025-12-25 10:12',
#    'dep_actual_utc': '2025-12-25 15:12',
#    'arr_iata': 'PNS',
#    'arr_icao': 'KPNS',
#    'arr_terminal': None,
#    'arr_gate': '4',
#    'arr_baggage': None,
#    'arr_time': '2025-12-24 21:47',
#    'arr_time_utc': '2025-12-25 03:47',
#    'arr_estimated': '2025-12-25 10:25',
#    'arr_estimated_utc': '2025-12-25 16:25',
#    'arr_actual': '2025-12-25 10:25',
#    'arr_actual_utc': '2025-12-25 16:25',
#    'cs_airline_iata': 'DL',
#    'cs_flight_number': '1473',
#    'cs_flight_iata': 'DL1473',
#    'status': 'landed',
#    'duration': 72,
#    'delayed': 758,
#    'dep_delayed': 757,
#    'arr_delayed': 758,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766634420,
#    'dep_time_ts': 1766630100,
#    'arr_estimated_ts': 1766679900,
#    'dep_estimated_ts': 1766675520,
#    'arr_actual_ts': 1766679900,
#    'dep_actual_ts': 1766675520},
#   {'airline_iata': 'DL',
#    'airline_icao': 'DAL',
#    'flight_iata': 'DL1473',
#    'flight_icao': 'DAL1473',
#    'flight_number': '1473',
#    'dep_iata': 'ATL',
#    'dep_icao': 'KATL',
#    'dep_terminal': 'S',
#    'dep_gate': 'B18',
#    'dep_time': '2025-12-24 21:35',
#    'dep_time_utc': '2025-12-25 02:35',
#    'dep_estimated': '2025-12-25 10:12',
#    'dep_estimated_utc': '2025-12-25 15:12',
#    'dep_actual': '2025-12-25 10:12',
#    'dep_actual_utc': '2025-12-25 15:12',
#    'arr_iata': 'PNS',
#    'arr_icao': 'KPNS',
#    'arr_terminal': None,
#    'arr_gate': '4',
#    'arr_baggage': None,
#    'arr_time': '2025-12-24 21:47',
#    'arr_time_utc': '2025-12-25 03:47',
#    'arr_estimated': '2025-12-25 10:25',
#    'arr_estimated_utc': '2025-12-25 16:25',
#    'arr_actual': '2025-12-25 10:25',
#    'arr_actual_utc': '2025-12-25 16:25',
#    'cs_airline_iata': None,
#    'cs_flight_number': None,
#    'cs_flight_iata': None,
#    'status': 'landed',
#    'duration': 72,
#    'delayed': 758,
#    'dep_delayed': 757,
#    'arr_delayed': 758,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766634420,
#    'dep_time_ts': 1766630100,
#    'arr_estimated_ts': 1766679900,
#    'dep_estimated_ts': 1766675520,
#    'arr_actual_ts': 1766679900,
#    'dep_actual_ts': 1766675520},
#   {'airline_iata': 'F9',
#    'airline_icao': 'FFT',
#    'flight_iata': 'F93054',
#    'flight_icao': 'FFT3054',
#    'flight_number': '3054',
#    'dep_iata': 'ATL',
#    'dep_icao': 'KATL',
#    'dep_terminal': 'S',
#    'dep_gate': 'C4',
#    'dep_time': '2025-12-24 22:50',
#    'dep_time_utc': '2025-12-25 03:50',
#    'dep_estimated': '2025-12-25 10:25',
#    'dep_estimated_utc': '2025-12-25 15:25',
#    'dep_actual': '2025-12-25 10:25',
#    'dep_actual_utc': '2025-12-25 15:25',
#    'arr_iata': 'TPA',
#    'arr_icao': 'KTPA',
#    'arr_terminal': None,
#    'arr_gate': 'E71',
#    'arr_baggage': '10',
#    'arr_time': '2025-12-25 00:26',
#    'arr_time_utc': '2025-12-25 05:26',
#    'arr_estimated': '2025-12-25 12:07',
#    'arr_estimated_utc': '2025-12-25 17:07',
#    'cs_airline_iata': None,
#    'cs_flight_number': None,
#    'cs_flight_iata': None,
#    'status': 'active',
#    'duration': 96,
#    'delayed': 701,
#    'dep_delayed': 695,
#    'arr_delayed': 701,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766640360,
#    'dep_time_ts': 1766634600,
#    'arr_estimated_ts': 1766682420,
#    'dep_estimated_ts': 1766676300,
#    'dep_actual_ts': 1766676300},
#   {'airline_iata': 'AA',
#    'airline_icao': 'AAL',
#    'flight_iata': 'AA127',
#    'flight_icao': 'AAL127',
#    'flight_number': '127',
#    'dep_iata': 'DFW',
#    'dep_icao': 'KDFW',
#    'dep_terminal': 'D',
#    'dep_gate': 'D36',
#    'dep_time': '2025-12-24 10:10',
#    'dep_time_utc': '2025-12-24 16:10',
#    'dep_estimated': '2025-12-25 09:31',
#    'dep_estimated_utc': '2025-12-25 15:31',
#    'dep_actual': '2025-12-25 09:31',
#    'dep_actual_utc': '2025-12-25 15:31',
#    'arr_iata': 'PVG',
#    'arr_icao': 'ZSPD',
#    'arr_terminal': '2',
#    'arr_gate': 'D79',
#    'arr_baggage': None,
#    'arr_time': '2025-12-25 16:25',
#    'arr_time_utc': '2025-12-25 08:25',
#    'arr_estimated': '2025-12-26 15:29',
#    'arr_estimated_utc': '2025-12-26 07:29',
#    'cs_airline_iata': None,
#    'cs_flight_number': None,
#    'cs_flight_iata': None,
#    'status': 'active',
#    'duration': 975,
#    'delayed': 1384,
#    'dep_delayed': 1401,
#    'arr_delayed': 1384,
#    'aircraft_icao': 'B772',
#    'arr_time_ts': 1766651100,
#    'dep_time_ts': 1766592600,
#    'arr_estimated_ts': 1766734140,
#    'dep_estimated_ts': 1766676660,
#    'dep_actual_ts': 1766676660},
#   {'airline_iata': 'CZ',
#    'airline_icao': 'CSN',
#    'flight_iata': 'CZ1620',
#    'flight_icao': 'CSN1620',
#    'flight_number': '1620',
#    'dep_iata': 'DFW',
#    'dep_icao': 'KDFW',
#    'dep_terminal': 'D',
#    'dep_gate': 'D36',
#    'dep_time': '2025-12-24 10:10',
#    'dep_time_utc': '2025-12-24 16:10',
#    'dep_estimated': '2025-12-25 09:31',
#    'dep_estimated_utc': '2025-12-25 15:31',
#    'dep_actual': '2025-12-25 09:31',
#    'dep_actual_utc': '2025-12-25 15:31',
#    'arr_iata': 'PVG',
#    'arr_icao': 'ZSPD',
#    'arr_terminal': '2',
#    'arr_gate': 'D79',
#    'arr_baggage': None,
#    'arr_time': '2025-12-25 16:25',
#    'arr_time_utc': '2025-12-25 08:25',
#    'arr_estimated': '2025-12-26 15:29',
#    'arr_estimated_utc': '2025-12-26 07:29',
#    'cs_airline_iata': 'AA',
#    'cs_flight_number': '127',
#    'cs_flight_iata': 'AA127',
#    'status': 'active',
#    'duration': 975,
#    'delayed': 1384,
#    'dep_delayed': 1401,
#    'arr_delayed': 1384,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766651100,
#    'dep_time_ts': 1766592600,
#    'arr_estimated_ts': 1766734140,
#    'dep_estimated_ts': 1766676660,
#    'dep_actual_ts': 1766676660},
#   {'airline_iata': 'VS',
#    'airline_icao': 'VIR',
#    'flight_iata': 'VS4601',
#    'flight_icao': 'VIR4601',
#    'flight_number': '4601',
#    'dep_iata': 'JFK',
#    'dep_icao': 'KJFK',
#    'dep_terminal': '4',
#    'dep_gate': 'B53',
#    'dep_time': '2025-12-25 08:30',
#    'dep_time_utc': '2025-12-25 13:30',
#    'dep_estimated': '2025-12-25 10:32',
#    'dep_estimated_utc': '2025-12-25 15:32',
#    'arr_iata': 'MSY',
#    'arr_icao': 'KMSY',
#    'arr_terminal': None,
#    'arr_gate': 'C8',
#    'arr_baggage': None,
#    'arr_time': '2025-12-25 11:14',
#    'arr_time_utc': '2025-12-25 17:14',
#    'arr_estimated': '2025-12-25 12:30',
#    'arr_estimated_utc': '2025-12-25 18:30',
#    'cs_airline_iata': 'DL',
#    'cs_flight_number': '1368',
#    'cs_flight_iata': 'DL1368',
#    'status': 'cancelled',
#    'duration': 224,
#    'delayed': 76,
#    'dep_delayed': 122,
#    'arr_delayed': 76,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766682840,
#    'dep_time_ts': 1766669400,
#    'arr_estimated_ts': 1766687400,
#    'dep_estimated_ts': 1766676720},
#   {'airline_iata': 'KQ',
#    'airline_icao': 'KQA',
#    'flight_iata': 'KQ7122',
#    'flight_icao': 'KQA7122',
#    'flight_number': '7122',
#    'dep_iata': 'JFK',
#    'dep_icao': 'KJFK',
#    'dep_terminal': '4',
#    'dep_gate': 'B53',
#    'dep_time': '2025-12-25 08:30',
#    'dep_time_utc': '2025-12-25 13:30',
#    'dep_estimated': '2025-12-25 10:32',
#    'dep_estimated_utc': '2025-12-25 15:32',
#    'arr_iata': 'MSY',
#    'arr_icao': 'KMSY',
#    'arr_terminal': None,
#    'arr_gate': 'C8',
#    'arr_baggage': None,
#    'arr_time': '2025-12-25 11:14',
#    'arr_time_utc': '2025-12-25 17:14',
#    'arr_estimated': '2025-12-25 12:30',
#    'arr_estimated_utc': '2025-12-25 18:30',
#    'cs_airline_iata': 'DL',
#    'cs_flight_number': '1368',
#    'cs_flight_iata': 'DL1368',
#    'status': 'cancelled',
#    'duration': 224,
#    'delayed': 76,
#    'dep_delayed': 122,
#    'arr_delayed': 76,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766682840,
#    'dep_time_ts': 1766669400,
#    'arr_estimated_ts': 1766687400,
#    'dep_estimated_ts': 1766676720},
#   {'airline_iata': 'LA',
#    'airline_icao': 'LAN',
#    'flight_iata': 'LA6819',
#    'flight_icao': 'LAN6819',
#    'flight_number': '6819',
#    'dep_iata': 'JFK',
#    'dep_icao': 'KJFK',
#    'dep_terminal': '4',
#    'dep_gate': 'B53',
#    'dep_time': '2025-12-25 08:30',
#    'dep_time_utc': '2025-12-25 13:30',
#    'dep_estimated': '2025-12-25 10:32',
#    'dep_estimated_utc': '2025-12-25 15:32',
#    'arr_iata': 'MSY',
#    'arr_icao': 'KMSY',
#    'arr_terminal': None,
#    'arr_gate': 'C8',
#    'arr_baggage': None,
#    'arr_time': '2025-12-25 11:14',
#    'arr_time_utc': '2025-12-25 17:14',
#    'arr_estimated': '2025-12-25 12:30',
#    'arr_estimated_utc': '2025-12-25 18:30',
#    'cs_airline_iata': 'DL',
#    'cs_flight_number': '1368',
#    'cs_flight_iata': 'DL1368',
#    'status': 'cancelled',
#    'duration': 224,
#    'delayed': 76,
#    'dep_delayed': 122,
#    'arr_delayed': 76,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766682840,
#    'dep_time_ts': 1766669400,
#    'arr_estimated_ts': 1766687400,
#    'dep_estimated_ts': 1766676720},
#   {'airline_iata': 'DL',
#    'airline_icao': 'DAL',
#    'flight_iata': 'DL1368',
#    'flight_icao': 'DAL1368',
#    'flight_number': '1368',
#    'dep_iata': 'JFK',
#    'dep_icao': 'KJFK',
#    'dep_terminal': '4',
#    'dep_gate': 'B53',
#    'dep_time': '2025-12-25 08:30',
#    'dep_time_utc': '2025-12-25 13:30',
#    'dep_estimated': '2025-12-25 10:32',
#    'dep_estimated_utc': '2025-12-25 15:32',
#    'arr_iata': 'MSY',
#    'arr_icao': 'KMSY',
#    'arr_terminal': None,
#    'arr_gate': 'C8',
#    'arr_baggage': None,
#    'arr_time': '2025-12-25 11:14',
#    'arr_time_utc': '2025-12-25 17:14',
#    'arr_estimated': '2025-12-25 12:30',
#    'arr_estimated_utc': '2025-12-25 18:30',
#    'cs_airline_iata': None,
#    'cs_flight_number': None,
#    'cs_flight_iata': None,
#    'status': 'cancelled',
#    'duration': 224,
#    'delayed': 76,
#    'dep_delayed': 122,
#    'arr_delayed': 76,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766682840,
#    'dep_time_ts': 1766669400,
#    'arr_estimated_ts': 1766687400,
#    'dep_estimated_ts': 1766676720},
#   {'airline_iata': '9E',
#    'airline_icao': 'EDV',
#    'flight_iata': '9E5432',
#    'flight_icao': 'EDV5432',
#    'flight_number': '5432',
#    'dep_iata': 'ATL',
#    'dep_icao': 'KATL',
#    'dep_terminal': 'S',
#    'dep_gate': 'D27',
#    'dep_time': '2025-12-25 09:30',
#    'dep_time_utc': '2025-12-25 14:30',
#    'dep_estimated': '2025-12-25 10:41',
#    'dep_estimated_utc': '2025-12-25 15:41',
#    'dep_actual': '2025-12-25 10:41',
#    'dep_actual_utc': '2025-12-25 15:41',
#    'arr_iata': 'GPT',
#    'arr_icao': 'KGPT',
#    'arr_terminal': None,
#    'arr_gate': None,
#    'arr_baggage': '4',
#    'arr_time': '2025-12-25 09:59',
#    'arr_time_utc': '2025-12-25 15:59',
#    'arr_estimated': '2025-12-25 11:03',
#    'arr_estimated_utc': '2025-12-25 17:03',
#    'cs_airline_iata': None,
#    'cs_flight_number': None,
#    'cs_flight_iata': None,
#    'status': 'active',
#    'duration': 89,
#    'delayed': 71,
#    'dep_delayed': 71,
#    'arr_delayed': 64,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766678340,
#    'dep_time_ts': 1766673000,
#    'arr_estimated_ts': 1766682180,
#    'dep_estimated_ts': 1766677260,
#    'dep_actual_ts': 1766677260},
#   {'airline_iata': 'DL',
#    'airline_icao': 'DAL',
#    'flight_iata': 'DL5432',
#    'flight_icao': 'DAL5432',
#    'flight_number': '5432',
#    'dep_iata': 'ATL',
#    'dep_icao': 'KATL',
#    'dep_terminal': 'S',
#    'dep_gate': 'D27',
#    'dep_time': '2025-12-25 09:30',
#    'dep_time_utc': '2025-12-25 14:30',
#    'dep_estimated': '2025-12-25 10:41',
#    'dep_estimated_utc': '2025-12-25 15:41',
#    'dep_actual': '2025-12-25 10:41',
#    'dep_actual_utc': '2025-12-25 15:41',
#    'arr_iata': 'GPT',
#    'arr_icao': 'KGPT',
#    'arr_terminal': None,
#    'arr_gate': None,
#    'arr_baggage': '4',
#    'arr_time': '2025-12-25 09:59',
#    'arr_time_utc': '2025-12-25 15:59',
#    'arr_estimated': '2025-12-25 11:03',
#    'arr_estimated_utc': '2025-12-25 17:03',
#    'cs_airline_iata': '9E',
#    'cs_flight_number': '5432',
#    'cs_flight_iata': '9E5432',
#    'status': 'active',
#    'duration': 89,
#    'delayed': 71,
#    'dep_delayed': 71,
#    'arr_delayed': 64,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766678340,
#    'dep_time_ts': 1766673000,
#    'arr_estimated_ts': 1766682180,
#    'dep_estimated_ts': 1766677260,
#    'dep_actual_ts': 1766677260},
#   {'airline_iata': 'WS',
#    'airline_icao': 'WJA',
#    'flight_iata': 'WS5470',
#    'flight_icao': 'WJA5470',
#    'flight_number': '5470',
#    'dep_iata': 'ATL',
#    'dep_icao': 'KATL',
#    'dep_terminal': 'S',
#    'dep_gate': 'D27',
#    'dep_time': '2025-12-25 09:30',
#    'dep_time_utc': '2025-12-25 14:30',
#    'dep_estimated': '2025-12-25 10:41',
#    'dep_estimated_utc': '2025-12-25 15:41',
#    'dep_actual': '2025-12-25 10:41',
#    'dep_actual_utc': '2025-12-25 15:41',
#    'arr_iata': 'GPT',
#    'arr_icao': 'KGPT',
#    'arr_terminal': None,
#    'arr_gate': None,
#    'arr_baggage': '4',
#    'arr_time': '2025-12-25 09:59',
#    'arr_time_utc': '2025-12-25 15:59',
#    'arr_estimated': '2025-12-25 11:03',
#    'arr_estimated_utc': '2025-12-25 17:03',
#    'cs_airline_iata': '9E',
#    'cs_flight_number': '5432',
#    'cs_flight_iata': '9E5432',
#    'status': 'active',
#    'duration': 89,
#    'delayed': 71,
#    'dep_delayed': 71,
#    'arr_delayed': 64,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766678340,
#    'dep_time_ts': 1766673000,
#    'arr_estimated_ts': 1766682180,
#    'dep_estimated_ts': 1766677260,
#    'dep_actual_ts': 1766677260},
#   {'airline_iata': 'GB',
#    'airline_icao': 'ABX',
#    'flight_iata': 'GB1102',
#    'flight_icao': 'ABX1102',
#    'flight_number': '1102',
#    'dep_iata': 'DFW',
#    'dep_icao': 'KDFW',
#    'dep_terminal': None,
#    'dep_gate': None,
#    'dep_time': '2025-12-25 08:30',
#    'dep_time_utc': '2025-12-25 14:30',
#    'dep_estimated': '2025-12-25 09:42',
#    'dep_estimated_utc': '2025-12-25 15:42',
#    'dep_actual': '2025-12-25 09:42',
#    'dep_actual_utc': '2025-12-25 15:42',
#    'arr_iata': 'CVG',
#    'arr_icao': 'KCVG',
#    'arr_terminal': None,
#    'arr_gate': None,
#    'arr_baggage': None,
#    'cs_airline_iata': None,
#    'cs_flight_number': None,
#    'cs_flight_iata': None,
#    'status': 'active',
#    'duration': None,
#    'delayed': 72,
#    'dep_delayed': 72,
#    'arr_delayed': None,
#    'aircraft_icao': None,
#    'dep_time_ts': 1766673000,
#    'dep_estimated_ts': 1766677320,
#    'dep_actual_ts': 1766677320},
#   {'airline_iata': 'LH',
#    'airline_icao': 'DLH',
#    'flight_iata': 'LH9376',
#    'flight_icao': 'DLH9376',
#    'flight_number': '9376',
#    'dep_iata': 'SFO',
#    'dep_icao': 'KSFO',
#    'dep_terminal': '3',
#    'dep_gate': 'F7',
#    'dep_time': '2025-12-24 16:25',
#    'dep_time_utc': '2025-12-25 00:25',
#    'dep_estimated': '2025-12-25 07:44',
#    'dep_estimated_utc': '2025-12-25 15:44',
#    'dep_actual': '2025-12-25 07:44',
#    'dep_actual_utc': '2025-12-25 15:44',
#    'arr_iata': 'SBP',
#    'arr_icao': 'KSBP',
#    'arr_terminal': None,
#    'arr_gate': None,
#    'arr_baggage': None,
#    'arr_time': '2025-12-24 17:34',
#    'arr_time_utc': '2025-12-25 01:34',
#    'arr_estimated': '2025-12-25 08:44',
#    'arr_estimated_utc': '2025-12-25 16:44',
#    'arr_actual': '2025-12-25 08:44',
#    'arr_actual_utc': '2025-12-25 16:44',
#    'cs_airline_iata': 'OO',
#    'cs_flight_number': '5693',
#    'cs_flight_iata': 'OO5693',
#    'status': 'landed',
#    'duration': 69,
#    'delayed': 910,
#    'dep_delayed': 919,
#    'arr_delayed': 910,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766626440,
#    'dep_time_ts': 1766622300,
#    'arr_estimated_ts': 1766681040,
#    'dep_estimated_ts': 1766677440,
#    'arr_actual_ts': 1766681040,
#    'dep_actual_ts': 1766677440},
#   {'airline_iata': 'EK',
#    'airline_icao': 'UAE',
#    'flight_iata': 'EK6384',
#    'flight_icao': 'UAE6384',
#    'flight_number': '6384',
#    'dep_iata': 'SFO',
#    'dep_icao': 'KSFO',
#    'dep_terminal': '3',
#    'dep_gate': 'F7',
#    'dep_time': '2025-12-24 16:25',
#    'dep_time_utc': '2025-12-25 00:25',
#    'dep_estimated': '2025-12-25 07:44',
#    'dep_estimated_utc': '2025-12-25 15:44',
#    'dep_actual': '2025-12-25 07:44',
#    'dep_actual_utc': '2025-12-25 15:44',
#    'arr_iata': 'SBP',
#    'arr_icao': 'KSBP',
#    'arr_terminal': None,
#    'arr_gate': None,
#    'arr_baggage': None,
#    'arr_time': '2025-12-24 17:34',
#    'arr_time_utc': '2025-12-25 01:34',
#    'arr_estimated': '2025-12-25 08:44',
#    'arr_estimated_utc': '2025-12-25 16:44',
#    'arr_actual': '2025-12-25 08:44',
#    'arr_actual_utc': '2025-12-25 16:44',
#    'cs_airline_iata': 'OO',
#    'cs_flight_number': '5693',
#    'cs_flight_iata': 'OO5693',
#    'status': 'landed',
#    'duration': 69,
#    'delayed': 910,
#    'dep_delayed': 919,
#    'arr_delayed': 910,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766626440,
#    'dep_time_ts': 1766622300,
#    'arr_estimated_ts': 1766681040,
#    'dep_estimated_ts': 1766677440,
#    'arr_actual_ts': 1766681040,
#    'dep_actual_ts': 1766677440},
#   {'airline_iata': 'OO',
#    'airline_icao': 'SKW',
#    'flight_iata': 'OO5693',
#    'flight_icao': 'SKW5693',
#    'flight_number': '5693',
#    'dep_iata': 'SFO',
#    'dep_icao': 'KSFO',
#    'dep_terminal': '3',
#    'dep_gate': 'F7',
#    'dep_time': '2025-12-24 16:25',
#    'dep_time_utc': '2025-12-25 00:25',
#    'dep_estimated': '2025-12-25 07:44',
#    'dep_estimated_utc': '2025-12-25 15:44',
#    'dep_actual': '2025-12-25 07:44',
#    'dep_actual_utc': '2025-12-25 15:44',
#    'arr_iata': 'SBP',
#    'arr_icao': 'KSBP',
#    'arr_terminal': None,
#    'arr_gate': None,
#    'arr_baggage': None,
#    'arr_time': '2025-12-24 17:34',
#    'arr_time_utc': '2025-12-25 01:34',
#    'arr_estimated': '2025-12-25 08:44',
#    'arr_estimated_utc': '2025-12-25 16:44',
#    'arr_actual': '2025-12-25 08:44',
#    'arr_actual_utc': '2025-12-25 16:44',
#    'cs_airline_iata': None,
#    'cs_flight_number': None,
#    'cs_flight_iata': None,
#    'status': 'landed',
#    'duration': 69,
#    'delayed': 910,
#    'dep_delayed': 919,
#    'arr_delayed': 910,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766626440,
#    'dep_time_ts': 1766622300,
#    'arr_estimated_ts': 1766681040,
#    'dep_estimated_ts': 1766677440,
#    'arr_actual_ts': 1766681040,
#    'dep_actual_ts': 1766677440},
#   {'airline_iata': 'UA',
#    'airline_icao': 'UAL',
#    'flight_iata': 'UA5693',
#    'flight_icao': 'UAL5693',
#    'flight_number': '5693',
#    'dep_iata': 'SFO',
#    'dep_icao': 'KSFO',
#    'dep_terminal': '3',
#    'dep_gate': 'F7',
#    'dep_time': '2025-12-24 16:25',
#    'dep_time_utc': '2025-12-25 00:25',
#    'dep_estimated': '2025-12-25 07:44',
#    'dep_estimated_utc': '2025-12-25 15:44',
#    'dep_actual': '2025-12-25 07:44',
#    'dep_actual_utc': '2025-12-25 15:44',
#    'arr_iata': 'SBP',
#    'arr_icao': 'KSBP',
#    'arr_terminal': None,
#    'arr_gate': None,
#    'arr_baggage': None,
#    'arr_time': '2025-12-24 17:34',
#    'arr_time_utc': '2025-12-25 01:34',
#    'arr_estimated': '2025-12-25 08:44',
#    'arr_estimated_utc': '2025-12-25 16:44',
#    'arr_actual': '2025-12-25 08:44',
#    'arr_actual_utc': '2025-12-25 16:44',
#    'cs_airline_iata': 'OO',
#    'cs_flight_number': '5693',
#    'cs_flight_iata': 'OO5693',
#    'status': 'landed',
#    'duration': 69,
#    'delayed': 910,
#    'dep_delayed': 919,
#    'arr_delayed': 910,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766626440,
#    'dep_time_ts': 1766622300,
#    'arr_estimated_ts': 1766681040,
#    'dep_estimated_ts': 1766677440,
#    'arr_actual_ts': 1766681040,
#    'dep_actual_ts': 1766677440},
#   {'airline_iata': 'AV',
#    'airline_icao': 'AVA',
#    'flight_iata': 'AV2103',
#    'flight_icao': 'AVA2103',
#    'flight_number': '2103',
#    'dep_iata': 'SFO',
#    'dep_icao': 'KSFO',
#    'dep_terminal': '3',
#    'dep_gate': 'F7',
#    'dep_time': '2025-12-24 16:25',
#    'dep_time_utc': '2025-12-25 00:25',
#    'dep_estimated': '2025-12-25 07:44',
#    'dep_estimated_utc': '2025-12-25 15:44',
#    'dep_actual': '2025-12-25 07:44',
#    'dep_actual_utc': '2025-12-25 15:44',
#    'arr_iata': 'SBP',
#    'arr_icao': 'KSBP',
#    'arr_terminal': None,
#    'arr_gate': None,
#    'arr_baggage': None,
#    'arr_time': '2025-12-24 17:34',
#    'arr_time_utc': '2025-12-25 01:34',
#    'arr_estimated': '2025-12-25 08:44',
#    'arr_estimated_utc': '2025-12-25 16:44',
#    'arr_actual': '2025-12-25 08:44',
#    'arr_actual_utc': '2025-12-25 16:44',
#    'cs_airline_iata': 'OO',
#    'cs_flight_number': '5693',
#    'cs_flight_iata': 'OO5693',
#    'status': 'landed',
#    'duration': 69,
#    'delayed': 910,
#    'dep_delayed': 919,
#    'arr_delayed': 910,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766626440,
#    'dep_time_ts': 1766622300,
#    'arr_estimated_ts': 1766681040,
#    'dep_estimated_ts': 1766677440,
#    'arr_actual_ts': 1766681040,
#    'dep_actual_ts': 1766677440},
#   {'airline_iata': 'F9',
#    'airline_icao': 'FFT',
#    'flight_iata': 'F94348',
#    'flight_icao': 'FFT4348',
#    'flight_number': '4348',
#    'dep_iata': 'ATL',
#    'dep_icao': 'KATL',
#    'dep_terminal': 'N',
#    'dep_gate': 'T17',
#    'dep_time': '2025-12-25 09:12',
#    'dep_time_utc': '2025-12-25 14:12',
#    'dep_estimated': '2025-12-25 10:59',
#    'dep_estimated_utc': '2025-12-25 15:59',
#    'dep_actual': '2025-12-25 10:59',
#    'dep_actual_utc': '2025-12-25 15:59',
#    'arr_iata': 'LGA',
#    'arr_icao': 'KLGA',
#    'arr_terminal': 'B',
#    'arr_gate': '42',
#    'arr_baggage': None,
#    'arr_time': '2025-12-25 11:29',
#    'arr_time_utc': '2025-12-25 16:29',
#    'arr_estimated': '2025-12-25 13:13',
#    'arr_estimated_utc': '2025-12-25 18:13',
#    'cs_airline_iata': None,
#    'cs_flight_number': None,
#    'cs_flight_iata': None,
#    'status': 'active',
#    'duration': 137,
#    'delayed': 104,
#    'dep_delayed': 107,
#    'arr_delayed': 104,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766680140,
#    'dep_time_ts': 1766671920,
#    'arr_estimated_ts': 1766686380,
#    'dep_estimated_ts': 1766678340,
#    'dep_actual_ts': 1766678340},
#   {'airline_iata': 'AA',
#    'airline_icao': 'AAL',
#    'flight_iata': 'AA1190',
#    'flight_icao': 'AAL1190',
#    'flight_number': '1190',
#    'dep_iata': 'DFW',
#    'dep_icao': 'KDFW',
#    'dep_terminal': 'B',
#    'dep_gate': 'B12',
#    'dep_time': '2025-12-25 08:16',
#    'dep_time_utc': '2025-12-25 14:16',
#    'dep_estimated': '2025-12-25 10:01',
#    'dep_estimated_utc': '2025-12-25 16:01',
#    'dep_actual': '2025-12-25 10:01',
#    'dep_actual_utc': '2025-12-25 16:01',
#    'arr_iata': 'CUN',
#    'arr_icao': 'MMUN',
#    'arr_terminal': '3',
#    'arr_gate': None,
#    'arr_baggage': None,
#    'arr_time': '2025-12-25 12:04',
#    'arr_time_utc': '2025-12-25 17:04',
#    'arr_estimated': '2025-12-25 13:36',
#    'arr_estimated_utc': '2025-12-25 18:36',
#    'cs_airline_iata': None,
#    'cs_flight_number': None,
#    'cs_flight_iata': None,
#    'status': 'active',
#    'duration': 168,
#    'delayed': 92,
#    'dep_delayed': 105,
#    'arr_delayed': 92,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766682240,
#    'dep_time_ts': 1766672160,
#    'arr_estimated_ts': 1766687760,
#    'dep_estimated_ts': 1766678460,
#    'dep_actual_ts': 1766678460},
#   {'airline_iata': 'IB',
#    'airline_icao': 'IBE',
#    'flight_iata': 'IB4490',
#    'flight_icao': 'IBE4490',
#    'flight_number': '4490',
#    'dep_iata': 'DFW',
#    'dep_icao': 'KDFW',
#    'dep_terminal': 'B',
#    'dep_gate': 'B12',
#    'dep_time': '2025-12-25 08:16',
#    'dep_time_utc': '2025-12-25 14:16',
#    'dep_estimated': '2025-12-25 10:01',
#    'dep_estimated_utc': '2025-12-25 16:01',
#    'dep_actual': '2025-12-25 10:01',
#    'dep_actual_utc': '2025-12-25 16:01',
#    'arr_iata': 'CUN',
#    'arr_icao': 'MMUN',
#    'arr_terminal': '3',
#    'arr_gate': None,
#    'arr_baggage': None,
#    'arr_time': '2025-12-25 12:04',
#    'arr_time_utc': '2025-12-25 17:04',
#    'arr_estimated': '2025-12-25 13:36',
#    'arr_estimated_utc': '2025-12-25 18:36',
#    'cs_airline_iata': 'AA',
#    'cs_flight_number': '1190',
#    'cs_flight_iata': 'AA1190',
#    'status': 'active',
#    'duration': 168,
#    'delayed': 92,
#    'dep_delayed': 105,
#    'arr_delayed': 92,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766682240,
#    'dep_time_ts': 1766672160,
#    'arr_estimated_ts': 1766687760,
#    'dep_estimated_ts': 1766678460,
#    'dep_actual_ts': 1766678460},
#   {'airline_iata': 'VS',
#    'airline_icao': 'VIR',
#    'flight_iata': 'VS5363',
#    'flight_icao': 'VIR5363',
#    'flight_number': '5363',
#    'dep_iata': 'ATL',
#    'dep_icao': 'KATL',
#    'dep_terminal': 'S',
#    'dep_gate': 'C30',
#    'dep_time': '2025-12-24 22:35',
#    'dep_time_utc': '2025-12-25 03:35',
#    'dep_estimated': '2025-12-25 11:02',
#    'dep_estimated_utc': '2025-12-25 16:02',
#    'dep_actual': '2025-12-25 11:02',
#    'dep_actual_utc': '2025-12-25 16:02',
#    'arr_iata': 'PNS',
#    'arr_icao': 'KPNS',
#    'arr_terminal': None,
#    'arr_gate': '4',
#    'arr_baggage': None,
#    'arr_time': '2025-12-24 22:49',
#    'arr_time_utc': '2025-12-25 04:49',
#    'arr_estimated': '2025-12-25 11:02',
#    'arr_estimated_utc': '2025-12-25 17:02',
#    'cs_airline_iata': 'DL',
#    'cs_flight_number': '1599',
#    'cs_flight_iata': 'DL1599',
#    'status': 'landed',
#    'duration': 74,
#    'delayed': 733,
#    'dep_delayed': 747,
#    'arr_delayed': 733,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766638140,
#    'dep_time_ts': 1766633700,
#    'arr_estimated_ts': 1766682120,
#    'dep_estimated_ts': 1766678520,
#    'dep_actual_ts': 1766678520},
#   {'airline_iata': 'DL',
#    'airline_icao': 'DAL',
#    'flight_iata': 'DL1599',
#    'flight_icao': 'DAL1599',
#    'flight_number': '1599',
#    'dep_iata': 'ATL',
#    'dep_icao': 'KATL',
#    'dep_terminal': 'S',
#    'dep_gate': 'C30',
#    'dep_time': '2025-12-24 22:35',
#    'dep_time_utc': '2025-12-25 03:35',
#    'dep_estimated': '2025-12-25 11:02',
#    'dep_estimated_utc': '2025-12-25 16:02',
#    'dep_actual': '2025-12-25 11:02',
#    'dep_actual_utc': '2025-12-25 16:02',
#    'arr_iata': 'PNS',
#    'arr_icao': 'KPNS',
#    'arr_terminal': None,
#    'arr_gate': '4',
#    'arr_baggage': None,
#    'arr_time': '2025-12-24 22:49',
#    'arr_time_utc': '2025-12-25 04:49',
#    'arr_estimated': '2025-12-25 11:02',
#    'arr_estimated_utc': '2025-12-25 17:02',
#    'cs_airline_iata': None,
#    'cs_flight_number': None,
#    'cs_flight_iata': None,
#    'status': 'landed',
#    'duration': 74,
#    'delayed': 733,
#    'dep_delayed': 747,
#    'arr_delayed': 733,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766638140,
#    'dep_time_ts': 1766633700,
#    'arr_estimated_ts': 1766682120,
#    'dep_estimated_ts': 1766678520,
#    'dep_actual_ts': 1766678520},
#   {'airline_iata': 'AM',
#    'airline_icao': 'AMX',
#    'flight_iata': 'AM3667',
#    'flight_icao': 'AMX3667',
#    'flight_number': '3667',
#    'dep_iata': 'ATL',
#    'dep_icao': 'KATL',
#    'dep_terminal': 'S',
#    'dep_gate': 'C30',
#    'dep_time': '2025-12-24 22:35',
#    'dep_time_utc': '2025-12-25 03:35',
#    'dep_estimated': '2025-12-25 11:02',
#    'dep_estimated_utc': '2025-12-25 16:02',
#    'dep_actual': '2025-12-25 11:02',
#    'dep_actual_utc': '2025-12-25 16:02',
#    'arr_iata': 'PNS',
#    'arr_icao': 'KPNS',
#    'arr_terminal': None,
#    'arr_gate': '4',
#    'arr_baggage': None,
#    'arr_time': '2025-12-24 22:49',
#    'arr_time_utc': '2025-12-25 04:49',
#    'arr_estimated': '2025-12-25 11:02',
#    'arr_estimated_utc': '2025-12-25 17:02',
#    'cs_airline_iata': 'DL',
#    'cs_flight_number': '1599',
#    'cs_flight_iata': 'DL1599',
#    'status': 'landed',
#    'duration': 74,
#    'delayed': 733,
#    'dep_delayed': 747,
#    'arr_delayed': 733,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766638140,
#    'dep_time_ts': 1766633700,
#    'arr_estimated_ts': 1766682120,
#    'dep_estimated_ts': 1766678520,
#    'dep_actual_ts': 1766678520},
#   {'airline_iata': 'LA',
#    'airline_icao': 'LAN',
#    'flight_iata': 'LA6563',
#    'flight_icao': 'LAN6563',
#    'flight_number': '6563',
#    'dep_iata': 'ATL',
#    'dep_icao': 'KATL',
#    'dep_terminal': 'S',
#    'dep_gate': 'C30',
#    'dep_time': '2025-12-24 22:35',
#    'dep_time_utc': '2025-12-25 03:35',
#    'dep_estimated': '2025-12-25 11:02',
#    'dep_estimated_utc': '2025-12-25 16:02',
#    'dep_actual': '2025-12-25 11:02',
#    'dep_actual_utc': '2025-12-25 16:02',
#    'arr_iata': 'PNS',
#    'arr_icao': 'KPNS',
#    'arr_terminal': None,
#    'arr_gate': '4',
#    'arr_baggage': None,
#    'arr_time': '2025-12-24 22:49',
#    'arr_time_utc': '2025-12-25 04:49',
#    'arr_estimated': '2025-12-25 11:02',
#    'arr_estimated_utc': '2025-12-25 17:02',
#    'cs_airline_iata': 'DL',
#    'cs_flight_number': '1599',
#    'cs_flight_iata': 'DL1599',
#    'status': 'landed',
#    'duration': 74,
#    'delayed': 733,
#    'dep_delayed': 747,
#    'arr_delayed': 733,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766638140,
#    'dep_time_ts': 1766633700,
#    'arr_estimated_ts': 1766682120,
#    'dep_estimated_ts': 1766678520,
#    'dep_actual_ts': 1766678520},
#   {'airline_iata': 'KE',
#    'airline_icao': 'KAL',
#    'flight_iata': 'KE7123',
#    'flight_icao': 'KAL7123',
#    'flight_number': '7123',
#    'dep_iata': 'ATL',
#    'dep_icao': 'KATL',
#    'dep_terminal': 'S',
#    'dep_gate': 'C30',
#    'dep_time': '2025-12-24 22:35',
#    'dep_time_utc': '2025-12-25 03:35',
#    'dep_estimated': '2025-12-25 11:02',
#    'dep_estimated_utc': '2025-12-25 16:02',
#    'dep_actual': '2025-12-25 11:02',
#    'dep_actual_utc': '2025-12-25 16:02',
#    'arr_iata': 'PNS',
#    'arr_icao': 'KPNS',
#    'arr_terminal': None,
#    'arr_gate': '4',
#    'arr_baggage': None,
#    'arr_time': '2025-12-24 22:49',
#    'arr_time_utc': '2025-12-25 04:49',
#    'arr_estimated': '2025-12-25 11:02',
#    'arr_estimated_utc': '2025-12-25 17:02',
#    'cs_airline_iata': 'DL',
#    'cs_flight_number': '1599',
#    'cs_flight_iata': 'DL1599',
#    'status': 'landed',
#    'duration': 74,
#    'delayed': 733,
#    'dep_delayed': 747,
#    'arr_delayed': 733,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766638140,
#    'dep_time_ts': 1766633700,
#    'arr_estimated_ts': 1766682120,
#    'dep_estimated_ts': 1766678520,
#    'dep_actual_ts': 1766678520},
#   {'airline_iata': 'KL',
#    'airline_icao': 'KLM',
#    'flight_iata': 'KL5174',
#    'flight_icao': 'KLM5174',
#    'flight_number': '5174',
#    'dep_iata': 'ATL',
#    'dep_icao': 'KATL',
#    'dep_terminal': 'S',
#    'dep_gate': 'C30',
#    'dep_time': '2025-12-24 22:35',
#    'dep_time_utc': '2025-12-25 03:35',
#    'dep_estimated': '2025-12-25 11:02',
#    'dep_estimated_utc': '2025-12-25 16:02',
#    'dep_actual': '2025-12-25 11:02',
#    'dep_actual_utc': '2025-12-25 16:02',
#    'arr_iata': 'PNS',
#    'arr_icao': 'KPNS',
#    'arr_terminal': None,
#    'arr_gate': '4',
#    'arr_baggage': None,
#    'arr_time': '2025-12-24 22:49',
#    'arr_time_utc': '2025-12-25 04:49',
#    'arr_estimated': '2025-12-25 11:02',
#    'arr_estimated_utc': '2025-12-25 17:02',
#    'cs_airline_iata': 'DL',
#    'cs_flight_number': '1599',
#    'cs_flight_iata': 'DL1599',
#    'status': 'landed',
#    'duration': 74,
#    'delayed': 733,
#    'dep_delayed': 747,
#    'arr_delayed': 733,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766638140,
#    'dep_time_ts': 1766633700,
#    'arr_estimated_ts': 1766682120,
#    'dep_estimated_ts': 1766678520,
#    'dep_actual_ts': 1766678520},
#   {'airline_iata': 'IB',
#    'airline_icao': 'IBE',
#    'flight_iata': 'IB4587',
#    'flight_icao': 'IBE4587',
#    'flight_number': '4587',
#    'dep_iata': 'DFW',
#    'dep_icao': 'KDFW',
#    'dep_terminal': 'A',
#    'dep_gate': 'A35',
#    'dep_time': '2025-12-25 08:30',
#    'dep_time_utc': '2025-12-25 14:30',
#    'dep_estimated': '2025-12-25 10:07',
#    'dep_estimated_utc': '2025-12-25 16:07',
#    'dep_actual': '2025-12-25 10:07',
#    'dep_actual_utc': '2025-12-25 16:07',
#    'arr_iata': 'IAH',
#    'arr_icao': 'KIAH',
#    'arr_terminal': 'A',
#    'arr_gate': '27',
#    'arr_baggage': '2',
#    'arr_time': '2025-12-25 09:55',
#    'arr_time_utc': '2025-12-25 15:55',
#    'arr_estimated': '2025-12-25 11:10',
#    'arr_estimated_utc': '2025-12-25 17:10',
#    'cs_airline_iata': 'AA',
#    'cs_flight_number': '2578',
#    'cs_flight_iata': 'AA2578',
#    'status': 'active',
#    'duration': 85,
#    'delayed': 75,
#    'dep_delayed': 97,
#    'arr_delayed': 75,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766678100,
#    'dep_time_ts': 1766673000,
#    'arr_estimated_ts': 1766682600,
#    'dep_estimated_ts': 1766678820,
#    'dep_actual_ts': 1766678820},
#   {'airline_iata': 'BA',
#    'airline_icao': 'BAW',
#    'flight_iata': 'BA1891',
#    'flight_icao': 'BAW1891',
#    'flight_number': '1891',
#    'dep_iata': 'DFW',
#    'dep_icao': 'KDFW',
#    'dep_terminal': 'A',
#    'dep_gate': 'A35',
#    'dep_time': '2025-12-25 08:30',
#    'dep_time_utc': '2025-12-25 14:30',
#    'dep_estimated': '2025-12-25 10:07',
#    'dep_estimated_utc': '2025-12-25 16:07',
#    'dep_actual': '2025-12-25 10:07',
#    'dep_actual_utc': '2025-12-25 16:07',
#    'arr_iata': 'IAH',
#    'arr_icao': 'KIAH',
#    'arr_terminal': 'A',
#    'arr_gate': '27',
#    'arr_baggage': '2',
#    'arr_time': '2025-12-25 09:55',
#    'arr_time_utc': '2025-12-25 15:55',
#    'arr_estimated': '2025-12-25 11:10',
#    'arr_estimated_utc': '2025-12-25 17:10',
#    'cs_airline_iata': 'AA',
#    'cs_flight_number': '2578',
#    'cs_flight_iata': 'AA2578',
#    'status': 'active',
#    'duration': 85,
#    'delayed': 75,
#    'dep_delayed': 97,
#    'arr_delayed': 75,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766678100,
#    'dep_time_ts': 1766673000,
#    'arr_estimated_ts': 1766682600,
#    'dep_estimated_ts': 1766678820,
#    'dep_actual_ts': 1766678820},
#   {'airline_iata': 'G3',
#    'airline_icao': 'GLO',
#    'flight_iata': 'G36117',
#    'flight_icao': 'GLO6117',
#    'flight_number': '6117',
#    'dep_iata': 'DFW',
#    'dep_icao': 'KDFW',
#    'dep_terminal': 'A',
#    'dep_gate': 'A35',
#    'dep_time': '2025-12-25 08:30',
#    'dep_time_utc': '2025-12-25 14:30',
#    'dep_estimated': '2025-12-25 10:07',
#    'dep_estimated_utc': '2025-12-25 16:07',
#    'dep_actual': '2025-12-25 10:07',
#    'dep_actual_utc': '2025-12-25 16:07',
#    'arr_iata': 'IAH',
#    'arr_icao': 'KIAH',
#    'arr_terminal': 'A',
#    'arr_gate': '27',
#    'arr_baggage': '2',
#    'arr_time': '2025-12-25 09:55',
#    'arr_time_utc': '2025-12-25 15:55',
#    'arr_estimated': '2025-12-25 11:10',
#    'arr_estimated_utc': '2025-12-25 17:10',
#    'cs_airline_iata': 'AA',
#    'cs_flight_number': '2578',
#    'cs_flight_iata': 'AA2578',
#    'status': 'active',
#    'duration': 85,
#    'delayed': 75,
#    'dep_delayed': 97,
#    'arr_delayed': 75,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766678100,
#    'dep_time_ts': 1766673000,
#    'arr_estimated_ts': 1766682600,
#    'dep_estimated_ts': 1766678820,
#    'dep_actual_ts': 1766678820},
#   {'airline_iata': 'AS',
#    'airline_icao': 'ASA',
#    'flight_iata': 'AS4180',
#    'flight_icao': 'ASA4180',
#    'flight_number': '4180',
#    'dep_iata': 'DFW',
#    'dep_icao': 'KDFW',
#    'dep_terminal': 'A',
#    'dep_gate': 'A35',
#    'dep_time': '2025-12-25 08:30',
#    'dep_time_utc': '2025-12-25 14:30',
#    'dep_estimated': '2025-12-25 10:07',
#    'dep_estimated_utc': '2025-12-25 16:07',
#    'dep_actual': '2025-12-25 10:07',
#    'dep_actual_utc': '2025-12-25 16:07',
#    'arr_iata': 'IAH',
#    'arr_icao': 'KIAH',
#    'arr_terminal': 'A',
#    'arr_gate': '27',
#    'arr_baggage': '2',
#    'arr_time': '2025-12-25 09:55',
#    'arr_time_utc': '2025-12-25 15:55',
#    'arr_estimated': '2025-12-25 11:10',
#    'arr_estimated_utc': '2025-12-25 17:10',
#    'cs_airline_iata': 'AA',
#    'cs_flight_number': '2578',
#    'cs_flight_iata': 'AA2578',
#    'status': 'active',
#    'duration': 85,
#    'delayed': 75,
#    'dep_delayed': 97,
#    'arr_delayed': 75,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766678100,
#    'dep_time_ts': 1766673000,
#    'arr_estimated_ts': 1766682600,
#    'dep_estimated_ts': 1766678820,
#    'dep_actual_ts': 1766678820},
#   {'airline_iata': 'AA',
#    'airline_icao': 'AAL',
#    'flight_iata': 'AA2578',
#    'flight_icao': 'AAL2578',
#    'flight_number': '2578',
#    'dep_iata': 'DFW',
#    'dep_icao': 'KDFW',
#    'dep_terminal': 'A',
#    'dep_gate': 'A35',
#    'dep_time': '2025-12-25 08:30',
#    'dep_time_utc': '2025-12-25 14:30',
#    'dep_estimated': '2025-12-25 10:07',
#    'dep_estimated_utc': '2025-12-25 16:07',
#    'dep_actual': '2025-12-25 10:07',
#    'dep_actual_utc': '2025-12-25 16:07',
#    'arr_iata': 'IAH',
#    'arr_icao': 'KIAH',
#    'arr_terminal': 'A',
#    'arr_gate': '27',
#    'arr_baggage': '2',
#    'arr_time': '2025-12-25 09:55',
#    'arr_time_utc': '2025-12-25 15:55',
#    'arr_estimated': '2025-12-25 11:10',
#    'arr_estimated_utc': '2025-12-25 17:10',
#    'cs_airline_iata': None,
#    'cs_flight_number': None,
#    'cs_flight_iata': None,
#    'status': 'active',
#    'duration': 85,
#    'delayed': 75,
#    'dep_delayed': 97,
#    'arr_delayed': 75,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766678100,
#    'dep_time_ts': 1766673000,
#    'arr_estimated_ts': 1766682600,
#    'dep_estimated_ts': 1766678820,
#    'dep_actual_ts': 1766678820},
#   {'airline_iata': 'AA',
#    'airline_icao': 'AAL',
#    'flight_iata': 'AA295',
#    'flight_icao': 'AAL295',
#    'flight_number': '295',
#    'dep_iata': 'DFW',
#    'dep_icao': 'KDFW',
#    'dep_terminal': 'A',
#    'dep_gate': 'A21',
#    'dep_time': '2025-12-25 09:05',
#    'dep_time_utc': '2025-12-25 15:05',
#    'dep_estimated': '2025-12-25 10:12',
#    'dep_estimated_utc': '2025-12-25 16:12',
#    'dep_actual': '2025-12-25 10:12',
#    'dep_actual_utc': '2025-12-25 16:12',
#    'arr_iata': 'OGG',
#    'arr_icao': 'PHOG',
#    'arr_terminal': None,
#    'arr_gate': None,
#    'arr_baggage': None,
#    'arr_time': '2025-12-25 13:17',
#    'arr_time_utc': '2025-12-25 23:17',
#    'arr_estimated': '2025-12-25 14:44',
#    'arr_estimated_utc': '2025-12-26 00:44',
#    'cs_airline_iata': None,
#    'cs_flight_number': None,
#    'cs_flight_iata': None,
#    'status': 'active',
#    'duration': 492,
#    'delayed': 87,
#    'dep_delayed': 67,
#    'arr_delayed': 87,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766704620,
#    'dep_time_ts': 1766675100,
#    'arr_estimated_ts': 1766709840,
#    'dep_estimated_ts': 1766679120,
#    'dep_actual_ts': 1766679120},
#   {'airline_iata': 'NK',
#    'airline_icao': 'NKS',
#    'flight_iata': 'NK1',
#    'flight_icao': 'NKS1',
#    'flight_number': '1',
#    'dep_iata': 'ORD',
#    'dep_icao': 'KORD',
#    'dep_terminal': '2',
#    'dep_gate': 'G12',
#    'dep_time': '2025-12-25 05:00',
#    'dep_time_utc': '2025-12-25 11:00',
#    'dep_estimated': '2025-12-25 10:20',
# ...
#    'arr_estimated_utc': '2025-12-25 18:41',
#    'cs_airline_iata': None,
#    'cs_flight_number': None,
#    'cs_flight_iata': None,
#    'status': 'scheduled',
#    'duration': 86,
#    'delayed': 824,
#    'dep_delayed': 824,
#    'arr_delayed': 824,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766638620,
#    'dep_time_ts': 1766633460,
#    'arr_estimated_ts': 1766688060,
#    'dep_estimated_ts': 1766682900},
#   {'airline_iata': 'DL',
#    'airline_icao': 'DAL',
#    'flight_iata': 'DL171',
#    'flight_icao': 'DAL171',
#    'flight_number': '171',
#    'dep_iata': 'MSP',
#    'dep_icao': 'KMSP',
#    'dep_terminal': '1',
#    'dep_gate': 'G8',
#    'dep_time': '2025-12-25 10:10',
#    'dep_time_utc': '2025-12-25 16:10',
#    'dep_estimated': '2025-12-25 11:25',
#    'dep_estimated_utc': '2025-12-25 17:25',
#    'arr_iata': 'ICN',
#    'arr_icao': 'RKSI',
#    'arr_terminal': '2',
#    'arr_gate': '265',
#    'arr_baggage': '13',
#    'arr_time': '2025-12-26 15:30',
#    'arr_time_utc': '2025-12-26 06:30',
#    'arr_estimated': '2025-12-26 16:49',
#    'arr_estimated_utc': '2025-12-26 07:49',
#    'cs_airline_iata': None,
#    'cs_flight_number': None,
#    'cs_flight_iata': None,
#    'status': 'scheduled',
#    'duration': 860,
#    'delayed': 75,
#    'dep_delayed': 75,
#    'arr_delayed': 79,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766730600,
#    'dep_time_ts': 1766679000,
#    'arr_estimated_ts': 1766735340,
#    'dep_estimated_ts': 1766683500},
#   {'airline_iata': 'KE',
#    'airline_icao': 'KAL',
#    'flight_iata': 'KE5034',
#    'flight_icao': 'KAL5034',
#    'flight_number': '5034',
#    'dep_iata': 'MSP',
#    'dep_icao': 'KMSP',
#    'dep_terminal': '1',
#    'dep_gate': 'G8',
#    'dep_time': '2025-12-25 10:10',
#    'dep_time_utc': '2025-12-25 16:10',
#    'dep_estimated': '2025-12-25 11:25',
#    'dep_estimated_utc': '2025-12-25 17:25',
#    'arr_iata': 'ICN',
#    'arr_icao': 'RKSI',
#    'arr_terminal': '2',
#    'arr_gate': '265',
#    'arr_baggage': '13',
#    'arr_time': '2025-12-26 15:30',
#    'arr_time_utc': '2025-12-26 06:30',
#    'arr_estimated': '2025-12-26 16:49',
#    'arr_estimated_utc': '2025-12-26 07:49',
#    'cs_airline_iata': 'DL',
#    'cs_flight_number': '171',
#    'cs_flight_iata': 'DL171',
#    'status': 'scheduled',
#    'duration': 860,
#    'delayed': 75,
#    'dep_delayed': 75,
#    'arr_delayed': 79,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766730600,
#    'dep_time_ts': 1766679000,
#    'arr_estimated_ts': 1766735340,
#    'dep_estimated_ts': 1766683500},
#   {'airline_iata': 'AA',
#    'airline_icao': 'AAL',
#    'flight_iata': 'AA2139',
#    'flight_icao': 'AAL2139',
#    'flight_number': '2139',
#    'dep_iata': 'DFW',
#    'dep_icao': 'KDFW',
#    'dep_terminal': 'C',
#    'dep_gate': 'C8',
#    'dep_time': '2025-12-25 08:17',
#    'dep_time_utc': '2025-12-25 14:17',
#    'dep_estimated': '2025-12-25 11:30',
#    'dep_estimated_utc': '2025-12-25 17:30',
#    'dep_actual': '2025-12-25 09:12',
#    'dep_actual_utc': '2025-12-25 15:12',
#    'arr_iata': 'MSN',
#    'arr_icao': 'KMSN',
#    'arr_terminal': None,
#    'arr_gate': None,
#    'arr_baggage': None,
#    'arr_time': '2025-12-25 10:37',
#    'arr_time_utc': '2025-12-25 16:37',
#    'arr_estimated': '2025-12-25 13:46',
#    'arr_estimated_utc': '2025-12-25 19:46',
#    'arr_actual': '2025-12-25 10:21',
#    'arr_actual_utc': '2025-12-25 16:21',
#    'cs_airline_iata': None,
#    'cs_flight_number': None,
#    'cs_flight_iata': None,
#    'status': 'scheduled',
#    'duration': 140,
#    'delayed': 189,
#    'dep_delayed': 193,
#    'arr_delayed': 189,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766680620,
#    'dep_time_ts': 1766672220,
#    'arr_estimated_ts': 1766691960,
#    'dep_estimated_ts': 1766683800,
#    'arr_actual_ts': 1766679660,
#    'dep_actual_ts': 1766675520},
#   {'airline_iata': 'WN',
#    'airline_icao': 'SWA',
#    'flight_iata': 'WN2630',
#    'flight_icao': 'SWA2630',
#    'flight_number': '2630',
#    'dep_iata': 'DEN',
#    'dep_icao': 'KDEN',
#    'dep_terminal': None,
#    'dep_gate': 'C48',
#    'dep_time': '2025-12-25 08:00',
#    'dep_time_utc': '2025-12-25 15:00',
#    'dep_estimated': '2025-12-25 10:30',
#    'dep_estimated_utc': '2025-12-25 17:30',
#    'arr_iata': 'SFO',
#    'arr_icao': 'KSFO',
#    'arr_terminal': '2',
#    'arr_gate': 'D3',
#    'arr_baggage': '3',
#    'arr_time': '2025-12-25 09:50',
#    'arr_time_utc': '2025-12-25 17:50',
#    'arr_estimated': '2025-12-25 12:16',
#    'arr_estimated_utc': '2025-12-25 20:16',
#    'cs_airline_iata': None,
#    'cs_flight_number': None,
#    'cs_flight_iata': None,
#    'status': 'scheduled',
#    'duration': 170,
#    'delayed': 146,
#    'dep_delayed': 150,
#    'arr_delayed': 146,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766685000,
#    'dep_time_ts': 1766674800,
#    'arr_estimated_ts': 1766693760,
#    'dep_estimated_ts': 1766683800},
#   {'airline_iata': 'CM',
#    'airline_icao': 'CMP',
#    'flight_iata': 'CM1328',
#    'flight_icao': 'CMP1328',
#    'flight_number': '1328',
#    'dep_iata': 'DFW',
#    'dep_icao': 'KDFW',
#    'dep_terminal': 'E',
#    'dep_gate': 'E6',
#    'dep_time': '2025-12-25 09:50',
#    'dep_time_utc': '2025-12-25 15:50',
#    'dep_estimated': '2025-12-25 11:30',
#    'dep_estimated_utc': '2025-12-25 17:30',
#    'arr_iata': 'IAH',
#    'arr_icao': 'KIAH',
#    'arr_terminal': 'C',
#    'arr_gate': '15',
#    'arr_baggage': 'C3',
#    'arr_time': '2025-12-25 11:10',
#    'arr_time_utc': '2025-12-25 17:10',
#    'arr_estimated': '2025-12-25 12:45',
#    'arr_estimated_utc': '2025-12-25 18:45',
#    'cs_airline_iata': 'UA',
#    'cs_flight_number': '2675',
#    'cs_flight_iata': 'UA2675',
#    'status': 'scheduled',
#    'duration': 80,
#    'delayed': 95,
#    'dep_delayed': 100,
#    'arr_delayed': 95,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766682600,
#    'dep_time_ts': 1766677800,
#    'arr_estimated_ts': 1766688300,
#    'dep_estimated_ts': 1766683800},
#   {'airline_iata': 'NZ',
#    'airline_icao': 'ANZ',
#    'flight_iata': 'NZ6531',
#    'flight_icao': 'ANZ6531',
#    'flight_number': '6531',
#    'dep_iata': 'DFW',
#    'dep_icao': 'KDFW',
#    'dep_terminal': 'E',
#    'dep_gate': 'E6',
#    'dep_time': '2025-12-25 09:50',
#    'dep_time_utc': '2025-12-25 15:50',
#    'dep_estimated': '2025-12-25 11:30',
#    'dep_estimated_utc': '2025-12-25 17:30',
#    'arr_iata': 'IAH',
#    'arr_icao': 'KIAH',
#    'arr_terminal': 'C',
#    'arr_gate': '15',
#    'arr_baggage': 'C3',
#    'arr_time': '2025-12-25 11:10',
#    'arr_time_utc': '2025-12-25 17:10',
#    'arr_estimated': '2025-12-25 12:45',
#    'arr_estimated_utc': '2025-12-25 18:45',
#    'cs_airline_iata': 'UA',
#    'cs_flight_number': '2675',
#    'cs_flight_iata': 'UA2675',
#    'status': 'scheduled',
#    'duration': 80,
#    'delayed': 95,
#    'dep_delayed': 100,
#    'arr_delayed': 95,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766682600,
#    'dep_time_ts': 1766677800,
#    'arr_estimated_ts': 1766688300,
#    'dep_estimated_ts': 1766683800},
#   {'airline_iata': 'UA',
#    'airline_icao': 'UAL',
#    'flight_iata': 'UA2675',
#    'flight_icao': 'UAL2675',
#    'flight_number': '2675',
#    'dep_iata': 'DFW',
#    'dep_icao': 'KDFW',
#    'dep_terminal': 'E',
#    'dep_gate': 'E6',
#    'dep_time': '2025-12-25 09:50',
#    'dep_time_utc': '2025-12-25 15:50',
#    'dep_estimated': '2025-12-25 11:30',
#    'dep_estimated_utc': '2025-12-25 17:30',
#    'arr_iata': 'IAH',
#    'arr_icao': 'KIAH',
#    'arr_terminal': 'C',
#    'arr_gate': '15',
#    'arr_baggage': 'C3',
#    'arr_time': '2025-12-25 11:10',
#    'arr_time_utc': '2025-12-25 17:10',
#    'arr_estimated': '2025-12-25 12:45',
#    'arr_estimated_utc': '2025-12-25 18:45',
#    'cs_airline_iata': None,
#    'cs_flight_number': None,
#    'cs_flight_iata': None,
#    'status': 'scheduled',
#    'duration': 80,
#    'delayed': 95,
#    'dep_delayed': 100,
#    'arr_delayed': 95,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766682600,
#    'dep_time_ts': 1766677800,
#    'arr_estimated_ts': 1766688300,
#    'dep_estimated_ts': 1766683800},
#   {'airline_iata': 'OO',
#    'airline_icao': 'SKW',
#    'flight_iata': 'OO3049',
#    'flight_icao': 'SKW3049',
#    'flight_number': '3049',
#    'dep_iata': 'SEA',
#    'dep_icao': 'KSEA',
#    'dep_terminal': None,
#    'dep_gate': 'C16E',
#    'dep_time': '2025-12-25 07:08',
#    'dep_time_utc': '2025-12-25 15:08',
#    'dep_estimated': '2025-12-25 09:38',
#    'dep_estimated_utc': '2025-12-25 17:38',
#    'arr_iata': 'SMF',
#    'arr_icao': 'KSMF',
#    'arr_terminal': 'B',
#    'arr_gate': '7',
#    'arr_baggage': '1',
#    'arr_time': '2025-12-25 09:09',
#    'arr_time_utc': '2025-12-25 17:09',
#    'arr_estimated': '2025-12-25 11:40',
#    'arr_estimated_utc': '2025-12-25 19:40',
#    'cs_airline_iata': None,
#    'cs_flight_number': None,
#    'cs_flight_iata': None,
#    'status': 'scheduled',
#    'duration': 121,
#    'delayed': 150,
#    'dep_delayed': 150,
#    'arr_delayed': 151,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766682540,
#    'dep_time_ts': 1766675280,
#    'arr_estimated_ts': 1766691600,
#    'dep_estimated_ts': 1766684280},
#   {'airline_iata': 'TN',
#    'airline_icao': 'THT',
#    'flight_iata': 'TN2458',
#    'flight_icao': 'THT2458',
#    'flight_number': '2458',
#    'dep_iata': 'SEA',
#    'dep_icao': 'KSEA',
#    'dep_terminal': None,
#    'dep_gate': 'C16E',
#    'dep_time': '2025-12-25 07:08',
#    'dep_time_utc': '2025-12-25 15:08',
#    'dep_estimated': '2025-12-25 09:38',
#    'dep_estimated_utc': '2025-12-25 17:38',
#    'arr_iata': 'SMF',
#    'arr_icao': 'KSMF',
#    'arr_terminal': 'B',
#    'arr_gate': '7',
#    'arr_baggage': '1',
#    'arr_time': '2025-12-25 09:09',
#    'arr_time_utc': '2025-12-25 17:09',
#    'arr_estimated': '2025-12-25 11:40',
#    'arr_estimated_utc': '2025-12-25 19:40',
#    'cs_airline_iata': 'OO',
#    'cs_flight_number': '3049',
#    'cs_flight_iata': 'OO3049',
#    'status': 'scheduled',
#    'duration': 121,
#    'delayed': 150,
#    'dep_delayed': 150,
#    'arr_delayed': 151,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766682540,
#    'dep_time_ts': 1766675280,
#    'arr_estimated_ts': 1766691600,
#    'dep_estimated_ts': 1766684280},
#   {'airline_iata': 'HA',
#    'airline_icao': 'HAL',
#    'flight_iata': 'HA6792',
#    'flight_icao': 'HAL6792',
#    'flight_number': '6792',
#    'dep_iata': 'SEA',
#    'dep_icao': 'KSEA',
#    'dep_terminal': None,
#    'dep_gate': 'C16E',
#    'dep_time': '2025-12-25 07:08',
#    'dep_time_utc': '2025-12-25 15:08',
#    'dep_estimated': '2025-12-25 09:38',
#    'dep_estimated_utc': '2025-12-25 17:38',
#    'arr_iata': 'SMF',
#    'arr_icao': 'KSMF',
#    'arr_terminal': 'B',
#    'arr_gate': '7',
#    'arr_baggage': '1',
#    'arr_time': '2025-12-25 09:09',
#    'arr_time_utc': '2025-12-25 17:09',
#    'arr_estimated': '2025-12-25 11:40',
#    'arr_estimated_utc': '2025-12-25 19:40',
#    'cs_airline_iata': 'OO',
#    'cs_flight_number': '3049',
#    'cs_flight_iata': 'OO3049',
#    'status': 'scheduled',
#    'duration': 121,
#    'delayed': 150,
#    'dep_delayed': 150,
#    'arr_delayed': 151,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766682540,
#    'dep_time_ts': 1766675280,
#    'arr_estimated_ts': 1766691600,
#    'dep_estimated_ts': 1766684280},
#   {'airline_iata': 'AS',
#    'airline_icao': 'ASA',
#    'flight_iata': 'AS3049',
#    'flight_icao': 'ASA3049',
#    'flight_number': '3049',
#    'dep_iata': 'SEA',
#    'dep_icao': 'KSEA',
#    'dep_terminal': None,
#    'dep_gate': 'C16E',
#    'dep_time': '2025-12-25 07:08',
#    'dep_time_utc': '2025-12-25 15:08',
#    'dep_estimated': '2025-12-25 09:38',
#    'dep_estimated_utc': '2025-12-25 17:38',
#    'arr_iata': 'SMF',
#    'arr_icao': 'KSMF',
#    'arr_terminal': 'B',
#    'arr_gate': '7',
#    'arr_baggage': '1',
#    'arr_time': '2025-12-25 09:09',
#    'arr_time_utc': '2025-12-25 17:09',
#    'arr_estimated': '2025-12-25 11:40',
#    'arr_estimated_utc': '2025-12-25 19:40',
#    'cs_airline_iata': 'OO',
#    'cs_flight_number': '3049',
#    'cs_flight_iata': 'OO3049',
#    'status': 'scheduled',
#    'duration': 121,
#    'delayed': 150,
#    'dep_delayed': 150,
#    'arr_delayed': 151,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766682540,
#    'dep_time_ts': 1766675280,
#    'arr_estimated_ts': 1766691600,
#    'dep_estimated_ts': 1766684280},
#   {'airline_iata': 'UA',
#    'airline_icao': 'UAL',
#    'flight_iata': 'UA435',
#    'flight_icao': 'UAL435',
#    'flight_number': '435',
#    'dep_iata': 'SFO',
#    'dep_icao': 'KSFO',
#    'dep_terminal': '3',
#    'dep_gate': 'F22',
#    'dep_time': '2025-12-25 08:30',
#    'dep_time_utc': '2025-12-25 16:30',
#    'dep_estimated': '2025-12-25 09:45',
#    'dep_estimated_utc': '2025-12-25 17:45',
#    'arr_iata': 'EWR',
#    'arr_icao': 'KEWR',
#    'arr_terminal': 'C',
#    'arr_gate': '110',
#    'arr_baggage': '6',
#    'arr_time': '2025-12-25 16:56',
#    'arr_time_utc': '2025-12-25 21:56',
#    'arr_estimated': '2025-12-25 17:45',
#    'arr_estimated_utc': '2025-12-25 22:45',
#    'cs_airline_iata': None,
#    'cs_flight_number': None,
#    'cs_flight_iata': None,
#    'status': 'scheduled',
#    'duration': 326,
#    'delayed': 75,
#    'dep_delayed': 75,
#    'arr_delayed': 49,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766699760,
#    'dep_time_ts': 1766680200,
#    'arr_estimated_ts': 1766702700,
#    'dep_estimated_ts': 1766684700},
#   {'airline_iata': 'VA',
#    'airline_icao': 'VOZ',
#    'flight_iata': 'VA8152',
#    'flight_icao': 'VOZ8152',
#    'flight_number': '8152',
#    'dep_iata': 'SFO',
#    'dep_icao': 'KSFO',
#    'dep_terminal': '3',
#    'dep_gate': 'F22',
#    'dep_time': '2025-12-25 08:30',
#    'dep_time_utc': '2025-12-25 16:30',
#    'dep_estimated': '2025-12-25 09:45',
#    'dep_estimated_utc': '2025-12-25 17:45',
#    'arr_iata': 'EWR',
#    'arr_icao': 'KEWR',
#    'arr_terminal': 'C',
#    'arr_gate': '110',
#    'arr_baggage': '6',
#    'arr_time': '2025-12-25 16:56',
#    'arr_time_utc': '2025-12-25 21:56',
#    'arr_estimated': '2025-12-25 17:45',
#    'arr_estimated_utc': '2025-12-25 22:45',
#    'cs_airline_iata': 'UA',
#    'cs_flight_number': '435',
#    'cs_flight_iata': 'UA435',
#    'status': 'scheduled',
#    'duration': 326,
#    'delayed': 75,
#    'dep_delayed': 75,
#    'arr_delayed': 49,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766699760,
#    'dep_time_ts': 1766680200,
#    'arr_estimated_ts': 1766702700,
#    'dep_estimated_ts': 1766684700},
#   {'airline_iata': 'SN',
#    'airline_icao': 'BEL',
#    'flight_iata': 'SN8942',
#    'flight_icao': 'BEL8942',
#    'flight_number': '8942',
#    'dep_iata': 'SFO',
#    'dep_icao': 'KSFO',
#    'dep_terminal': '3',
#    'dep_gate': 'F22',
#    'dep_time': '2025-12-25 08:30',
#    'dep_time_utc': '2025-12-25 16:30',
#    'dep_estimated': '2025-12-25 09:45',
#    'dep_estimated_utc': '2025-12-25 17:45',
#    'arr_iata': 'EWR',
#    'arr_icao': 'KEWR',
#    'arr_terminal': 'C',
#    'arr_gate': '110',
#    'arr_baggage': '6',
#    'arr_time': '2025-12-25 16:56',
#    'arr_time_utc': '2025-12-25 21:56',
#    'arr_estimated': '2025-12-25 17:45',
#    'arr_estimated_utc': '2025-12-25 22:45',
#    'cs_airline_iata': 'UA',
#    'cs_flight_number': '435',
#    'cs_flight_iata': 'UA435',
#    'status': 'scheduled',
#    'duration': 326,
#    'delayed': 75,
#    'dep_delayed': 75,
#    'arr_delayed': 49,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766699760,
#    'dep_time_ts': 1766680200,
#    'arr_estimated_ts': 1766702700,
#    'dep_estimated_ts': 1766684700},
#   {'airline_iata': 'TP',
#    'airline_icao': 'TAP',
#    'flight_iata': 'TP8491',
#    'flight_icao': 'TAP8491',
#    'flight_number': '8491',
#    'dep_iata': 'SFO',
#    'dep_icao': 'KSFO',
#    'dep_terminal': '3',
#    'dep_gate': 'F22',
#    'dep_time': '2025-12-25 08:30',
#    'dep_time_utc': '2025-12-25 16:30',
#    'dep_estimated': '2025-12-25 09:45',
#    'dep_estimated_utc': '2025-12-25 17:45',
#    'arr_iata': 'EWR',
#    'arr_icao': 'KEWR',
#    'arr_terminal': 'C',
#    'arr_gate': '110',
#    'arr_baggage': '6',
#    'arr_time': '2025-12-25 16:56',
#    'arr_time_utc': '2025-12-25 21:56',
#    'arr_estimated': '2025-12-25 17:45',
#    'arr_estimated_utc': '2025-12-25 22:45',
#    'cs_airline_iata': 'UA',
#    'cs_flight_number': '435',
#    'cs_flight_iata': 'UA435',
#    'status': 'scheduled',
#    'duration': 326,
#    'delayed': 75,
#    'dep_delayed': 75,
#    'arr_delayed': 49,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766699760,
#    'dep_time_ts': 1766680200,
#    'arr_estimated_ts': 1766702700,
#    'dep_estimated_ts': 1766684700}],
#  'terms': "Unauthorized access is prohibited and punishable by law. \nReselling data 'As Is' without AirLabs.Co permission is strictly prohibited. \nFull terms on https://airlabs.co/. \nContact us info@airlabs.co"}

# %%
df = pd.DataFrame(data['response'])

# %% [markdown]
# Now I will Collect Data from the flight delay API with different delays parameter and eggragate the data for analysis.

# %%
# delays = [0, 30, 45, 90, 120]
params = {
    "api_key": API_KEY,
    "delay": 120,
    "type": "departures",
    "dep_icao": "EGLL,LFPG,EDDF,EHAM,LEMD,LIRF",
    "max": 100,}

response2 = requests.get(API_URL, params=params)

data2 = response2.json()
data2
# Out:
# {'request': {'lang': 'en',
#   'currency': 'USD',
#   'time': 11,
#   'id': 'lzv4xk20v0g',
#   'server': 'b',
#   'host': 'airlabs.co',
#   'pid': 860155,
#   'key': {'id': 37729,
#    'api_key': '2f1914c4-fa35-4b93-9894-de62a5d49aa7',
#    'type': 'free',
#    'expired': '2026-01-25T00:00:00.000Z',
#    'registered': '2025-12-25T02:41:57.000Z',
#    'upgraded': None,
#    'limits_by_hour': 2500,
#    'limits_by_minute': 250,
#    'limits_by_month': 1000,
#    'limits_total': 1000},
#   'params': {'delay': '120',
#    'type': 'departures',
#    'dep_icao': 'EGLL,LFPG,EDDF,EHAM,LEMD,LIRF',
#    'max': '100',
#    'lang': 'en'},
#   'version': 9,
#   'method': 'delays',
#   'client': {'ip': '2607:fb91:4b0c:a7e3:cdbb:ed9c:7976:e9be',
#    'geo': {'country_code': 'US',
#     'country': 'United States',
#     'continent': 'North America',
#     'lat': 37.751,
#     'lng': -97.822,
#     'timezone': 'America/Chicago'},
#    'connection': {},
#    'device': {},
#    'agent': {},
#    'karma': {'is_blocked': False,
#     'is_crawler': False,
#     'is_bot': False,
#     'is_friend': False,
#     'is_regular': True}},
#   'has_more': False,
#   'total_items': 13},
#  'response': [{'airline_iata': 'AA',
#    'airline_icao': 'AAL',
#    'flight_iata': 'AA239',
#    'flight_icao': 'AAL239',
#    'flight_number': '239',
#    'dep_iata': 'FCO',
#    'dep_icao': 'LIRF',
#    'dep_terminal': '3',
#    'dep_gate': None,
#    'dep_time': '2025-12-23 13:10',
#    'dep_time_utc': '2025-12-23 12:10',
#    'dep_estimated': '2025-12-25 08:00',
#    'dep_estimated_utc': '2025-12-25 07:00',
#    'arr_iata': 'DFW',
#    'arr_icao': 'KDFW',
#    'arr_terminal': 'D',
#    'arr_gate': 'D23',
#    'arr_baggage': 'CUST',
#    'arr_time': '2025-12-23 18:25',
#    'arr_time_utc': '2025-12-24 00:25',
#    'arr_estimated': '2025-12-25 13:14',
#    'arr_estimated_utc': '2025-12-25 19:14',
#    'cs_airline_iata': None,
#    'cs_flight_number': None,
#    'cs_flight_iata': None,
#    'status': 'cancelled',
#    'duration': 735,
#    'delayed': 2570,
#    'dep_delayed': 2570,
#    'arr_delayed': 2569,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766535900,
#    'dep_time_ts': 1766491800,
#    'arr_estimated_ts': 1766690040,
#    'dep_estimated_ts': 1766646000},
#   {'airline_iata': 'AI',
#    'airline_icao': 'AIC',
#    'flight_iata': 'AI2030',
#    'flight_icao': 'AIC2030',
#    'flight_number': '2030',
#    'dep_iata': 'FRA',
#    'dep_icao': 'EDDF',
#    'dep_terminal': '1',
#    'dep_gate': None,
#    'dep_time': '2025-12-24 20:30',
#    'dep_time_utc': '2025-12-24 19:30',
#    'dep_estimated': '2025-12-25 08:00',
#    'dep_estimated_utc': '2025-12-25 07:00',
#    'arr_iata': 'DEL',
#    'arr_icao': 'VIDP',
#    'arr_terminal': '3',
#    'arr_gate': None,
#    'arr_baggage': '9',
#    'arr_time': '2025-12-25 10:00',
#    'arr_time_utc': '2025-12-25 04:30',
#    'cs_airline_iata': None,
#    'cs_flight_number': None,
#    'cs_flight_iata': None,
#    'status': 'scheduled',
#    'duration': 540,
#    'delayed': 690,
#    'dep_delayed': 690,
#    'arr_delayed': None,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766637000,
#    'dep_time_ts': 1766604600,
#    'dep_estimated_ts': 1766646000},
#   {'airline_iata': 'AY',
#    'airline_icao': 'FIN',
#    'flight_iata': 'AY3824',
#    'flight_icao': 'FIN3824',
#    'flight_number': '3824',
#    'dep_iata': 'FCO',
#    'dep_icao': 'LIRF',
#    'dep_terminal': '3',
#    'dep_gate': None,
#    'dep_time': '2025-12-23 13:10',
#    'dep_time_utc': '2025-12-23 12:10',
#    'dep_estimated': '2025-12-25 08:00',
#    'dep_estimated_utc': '2025-12-25 07:00',
#    'arr_iata': 'DFW',
#    'arr_icao': 'KDFW',
#    'arr_terminal': 'D',
#    'arr_gate': 'D23',
#    'arr_baggage': 'CUST',
#    'arr_time': '2025-12-23 18:25',
#    'arr_time_utc': '2025-12-24 00:25',
#    'arr_estimated': '2025-12-25 13:14',
#    'arr_estimated_utc': '2025-12-25 19:14',
#    'cs_airline_iata': 'AA',
#    'cs_flight_number': '239',
#    'cs_flight_iata': 'AA239',
#    'status': 'cancelled',
#    'duration': 735,
#    'delayed': 2570,
#    'dep_delayed': 2570,
#    'arr_delayed': 2569,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766535900,
#    'dep_time_ts': 1766491800,
#    'arr_estimated_ts': 1766690040,
#    'dep_estimated_ts': 1766646000},
#   {'airline_iata': 'BA',
#    'airline_icao': 'BAW',
#    'flight_iata': 'BA1628',
#    'flight_icao': 'BAW1628',
#    'flight_number': '1628',
#    'dep_iata': 'FCO',
#    'dep_icao': 'LIRF',
#    'dep_terminal': '3',
#    'dep_gate': None,
#    'dep_time': '2025-12-23 13:10',
#    'dep_time_utc': '2025-12-23 12:10',
#    'dep_estimated': '2025-12-25 08:00',
#    'dep_estimated_utc': '2025-12-25 07:00',
#    'arr_iata': 'DFW',
#    'arr_icao': 'KDFW',
#    'arr_terminal': 'D',
#    'arr_gate': 'D23',
#    'arr_baggage': 'CUST',
#    'arr_time': '2025-12-23 18:25',
#    'arr_time_utc': '2025-12-24 00:25',
#    'arr_estimated': '2025-12-25 13:14',
#    'arr_estimated_utc': '2025-12-25 19:14',
#    'cs_airline_iata': 'AA',
#    'cs_flight_number': '239',
#    'cs_flight_iata': 'AA239',
#    'status': 'cancelled',
#    'duration': 735,
#    'delayed': 2570,
#    'dep_delayed': 2570,
#    'arr_delayed': 2569,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766535900,
#    'dep_time_ts': 1766491800,
#    'arr_estimated_ts': 1766690040,
#    'dep_estimated_ts': 1766646000},
#   {'airline_iata': 'IB',
#    'airline_icao': 'IBE',
#    'flight_iata': 'IB8219',
#    'flight_icao': 'IBE8219',
#    'flight_number': '8219',
#    'dep_iata': 'FCO',
#    'dep_icao': 'LIRF',
#    'dep_terminal': '3',
#    'dep_gate': None,
#    'dep_time': '2025-12-23 13:10',
#    'dep_time_utc': '2025-12-23 12:10',
#    'dep_estimated': '2025-12-25 08:00',
#    'dep_estimated_utc': '2025-12-25 07:00',
#    'arr_iata': 'DFW',
#    'arr_icao': 'KDFW',
#    'arr_terminal': 'D',
#    'arr_gate': 'D23',
#    'arr_baggage': 'CUST',
#    'arr_time': '2025-12-23 18:25',
#    'arr_time_utc': '2025-12-24 00:25',
#    'arr_estimated': '2025-12-25 13:14',
#    'arr_estimated_utc': '2025-12-25 19:14',
#    'cs_airline_iata': 'AA',
#    'cs_flight_number': '239',
#    'cs_flight_iata': 'AA239',
#    'status': 'cancelled',
#    'duration': 735,
#    'delayed': 2570,
#    'dep_delayed': 2570,
#    'arr_delayed': 2569,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766535900,
#    'dep_time_ts': 1766491800,
#    'arr_estimated_ts': 1766690040,
#    'dep_estimated_ts': 1766646000},
#   {'airline_iata': 'LH',
#    'airline_icao': 'DLH',
#    'flight_iata': 'LH7252',
#    'flight_icao': 'DLH7252',
#    'flight_number': '7252',
#    'dep_iata': 'FRA',
#    'dep_icao': 'EDDF',
#    'dep_terminal': '1',
#    'dep_gate': None,
#    'dep_time': '2025-12-24 20:30',
#    'dep_time_utc': '2025-12-24 19:30',
#    'dep_estimated': '2025-12-25 08:00',
#    'dep_estimated_utc': '2025-12-25 07:00',
#    'arr_iata': 'DEL',
#    'arr_icao': 'VIDP',
#    'arr_terminal': '3',
#    'arr_gate': None,
#    'arr_baggage': '9',
#    'arr_time': '2025-12-25 10:00',
#    'arr_time_utc': '2025-12-25 04:30',
#    'cs_airline_iata': 'AI',
#    'cs_flight_number': '2030',
#    'cs_flight_iata': 'AI2030',
#    'status': 'scheduled',
#    'duration': 540,
#    'delayed': 690,
#    'dep_delayed': 690,
#    'arr_delayed': None,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766637000,
#    'dep_time_ts': 1766604600,
#    'dep_estimated_ts': 1766646000},
#   {'airline_iata': 'SQ',
#    'airline_icao': 'SIA',
#    'flight_iata': 'SQ4926',
#    'flight_icao': 'SIA4926',
#    'flight_number': '4926',
#    'dep_iata': 'FRA',
#    'dep_icao': 'EDDF',
#    'dep_terminal': '1',
#    'dep_gate': None,
#    'dep_time': '2025-12-24 20:30',
#    'dep_time_utc': '2025-12-24 19:30',
#    'dep_estimated': '2025-12-25 08:00',
#    'dep_estimated_utc': '2025-12-25 07:00',
#    'arr_iata': 'DEL',
#    'arr_icao': 'VIDP',
#    'arr_terminal': '3',
#    'arr_gate': None,
#    'arr_baggage': '9',
#    'arr_time': '2025-12-25 10:00',
#    'arr_time_utc': '2025-12-25 04:30',
#    'cs_airline_iata': 'AI',
#    'cs_flight_number': '2030',
#    'cs_flight_iata': 'AI2030',
#    'status': 'scheduled',
#    'duration': 540,
#    'delayed': 690,
#    'dep_delayed': 690,
#    'arr_delayed': None,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766637000,
#    'dep_time_ts': 1766604600,
#    'dep_estimated_ts': 1766646000},
#   {'airline_iata': 'TP',
#    'airline_icao': 'TAP',
#    'flight_iata': 'TP7044',
#    'flight_icao': 'TAP7044',
#    'flight_number': '7044',
#    'dep_iata': 'FRA',
#    'dep_icao': 'EDDF',
#    'dep_terminal': '1',
#    'dep_gate': None,
#    'dep_time': '2025-12-24 20:30',
#    'dep_time_utc': '2025-12-24 19:30',
#    'dep_estimated': '2025-12-25 08:00',
#    'dep_estimated_utc': '2025-12-25 07:00',
#    'arr_iata': 'DEL',
#    'arr_icao': 'VIDP',
#    'arr_terminal': '3',
#    'arr_gate': None,
#    'arr_baggage': '9',
#    'arr_time': '2025-12-25 10:00',
#    'arr_time_utc': '2025-12-25 04:30',
#    'cs_airline_iata': 'AI',
#    'cs_flight_number': '2030',
#    'cs_flight_iata': 'AI2030',
#    'status': 'scheduled',
#    'duration': 540,
#    'delayed': 690,
#    'dep_delayed': 690,
#    'arr_delayed': None,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766637000,
#    'dep_time_ts': 1766604600,
#    'dep_estimated_ts': 1766646000},
#   {'airline_iata': 'AA',
#    'airline_icao': 'AAL',
#    'flight_iata': 'AA79',
#    'flight_icao': 'AAL79',
#    'flight_number': '79',
#    'dep_iata': 'LHR',
#    'dep_icao': 'EGLL',
#    'dep_terminal': '3',
#    'dep_gate': None,
#    'dep_time': '2025-12-24 11:55',
#    'dep_time_utc': '2025-12-24 11:55',
#    'dep_estimated': '2025-12-26 08:00',
#    'dep_estimated_utc': '2025-12-26 08:00',
#    'arr_iata': 'DFW',
#    'arr_icao': 'KDFW',
#    'arr_terminal': 'D',
#    'arr_gate': 'D23',
#    'arr_baggage': 'CUST',
#    'arr_time': '2025-12-24 16:25',
#    'arr_time_utc': '2025-12-24 22:25',
#    'arr_estimated': '2025-12-26 12:29',
#    'arr_estimated_utc': '2025-12-26 18:29',
#    'cs_airline_iata': None,
#    'cs_flight_number': None,
#    'cs_flight_iata': None,
#    'status': 'cancelled',
#    'duration': 630,
#    'delayed': 2645,
#    'dep_delayed': 2645,
#    'arr_delayed': 2644,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766615100,
#    'dep_time_ts': 1766577300,
#    'arr_estimated_ts': 1766773740,
#    'dep_estimated_ts': 1766736000},
#   {'airline_iata': 'AY',
#    'airline_icao': 'FIN',
#    'flight_iata': 'AY3761',
#    'flight_icao': 'FIN3761',
#    'flight_number': '3761',
#    'dep_iata': 'LHR',
#    'dep_icao': 'EGLL',
#    'dep_terminal': '3',
#    'dep_gate': None,
#    'dep_time': '2025-12-24 11:55',
#    'dep_time_utc': '2025-12-24 11:55',
#    'dep_estimated': '2025-12-26 08:00',
#    'dep_estimated_utc': '2025-12-26 08:00',
#    'arr_iata': 'DFW',
#    'arr_icao': 'KDFW',
#    'arr_terminal': 'D',
#    'arr_gate': 'D23',
#    'arr_baggage': 'CUST',
#    'arr_time': '2025-12-24 16:25',
#    'arr_time_utc': '2025-12-24 22:25',
#    'arr_estimated': '2025-12-26 12:29',
#    'arr_estimated_utc': '2025-12-26 18:29',
#    'cs_airline_iata': 'AA',
#    'cs_flight_number': '79',
#    'cs_flight_iata': 'AA79',
#    'status': 'cancelled',
#    'duration': 630,
#    'delayed': 2645,
#    'dep_delayed': 2645,
#    'arr_delayed': 2644,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766615100,
#    'dep_time_ts': 1766577300,
#    'arr_estimated_ts': 1766773740,
#    'dep_estimated_ts': 1766736000},
#   {'airline_iata': 'BA',
#    'airline_icao': 'BAW',
#    'flight_iata': 'BA1520',
#    'flight_icao': 'BAW1520',
#    'flight_number': '1520',
#    'dep_iata': 'LHR',
#    'dep_icao': 'EGLL',
#    'dep_terminal': '3',
#    'dep_gate': None,
#    'dep_time': '2025-12-24 11:55',
#    'dep_time_utc': '2025-12-24 11:55',
#    'dep_estimated': '2025-12-26 08:00',
#    'dep_estimated_utc': '2025-12-26 08:00',
#    'arr_iata': 'DFW',
#    'arr_icao': 'KDFW',
#    'arr_terminal': 'D',
#    'arr_gate': 'D23',
#    'arr_baggage': 'CUST',
#    'arr_time': '2025-12-24 16:25',
#    'arr_time_utc': '2025-12-24 22:25',
#    'arr_estimated': '2025-12-26 12:29',
#    'arr_estimated_utc': '2025-12-26 18:29',
#    'cs_airline_iata': 'AA',
#    'cs_flight_number': '79',
#    'cs_flight_iata': 'AA79',
#    'status': 'cancelled',
#    'duration': 630,
#    'delayed': 2645,
#    'dep_delayed': 2645,
#    'arr_delayed': 2644,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766615100,
#    'dep_time_ts': 1766577300,
#    'arr_estimated_ts': 1766773740,
#    'dep_estimated_ts': 1766736000},
#   {'airline_iata': 'GF',
#    'airline_icao': 'GFA',
#    'flight_iata': 'GF4387',
#    'flight_icao': 'GFA4387',
#    'flight_number': '4387',
#    'dep_iata': 'LHR',
#    'dep_icao': 'EGLL',
#    'dep_terminal': '3',
#    'dep_gate': None,
#    'dep_time': '2025-12-24 11:55',
#    'dep_time_utc': '2025-12-24 11:55',
#    'dep_estimated': '2025-12-26 08:00',
#    'dep_estimated_utc': '2025-12-26 08:00',
#    'arr_iata': 'DFW',
#    'arr_icao': 'KDFW',
#    'arr_terminal': 'D',
#    'arr_gate': 'D23',
#    'arr_baggage': 'CUST',
#    'arr_time': '2025-12-24 16:25',
#    'arr_time_utc': '2025-12-24 22:25',
#    'arr_estimated': '2025-12-26 12:29',
#    'arr_estimated_utc': '2025-12-26 18:29',
#    'cs_airline_iata': 'AA',
#    'cs_flight_number': '79',
#    'cs_flight_iata': 'AA79',
#    'status': 'cancelled',
#    'duration': 630,
#    'delayed': 2645,
#    'dep_delayed': 2645,
#    'arr_delayed': 2644,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766615100,
#    'dep_time_ts': 1766577300,
#    'arr_estimated_ts': 1766773740,
#    'dep_estimated_ts': 1766736000},
#   {'airline_iata': 'IB',
#    'airline_icao': 'IBE',
#    'flight_iata': 'IB4205',
#    'flight_icao': 'IBE4205',
#    'flight_number': '4205',
#    'dep_iata': 'LHR',
#    'dep_icao': 'EGLL',
#    'dep_terminal': '3',
#    'dep_gate': None,
#    'dep_time': '2025-12-24 11:55',
#    'dep_time_utc': '2025-12-24 11:55',
#    'dep_estimated': '2025-12-26 08:00',
#    'dep_estimated_utc': '2025-12-26 08:00',
#    'arr_iata': 'DFW',
#    'arr_icao': 'KDFW',
#    'arr_terminal': 'D',
#    'arr_gate': 'D23',
#    'arr_baggage': 'CUST',
#    'arr_time': '2025-12-24 16:25',
#    'arr_time_utc': '2025-12-24 22:25',
#    'arr_estimated': '2025-12-26 12:29',
#    'arr_estimated_utc': '2025-12-26 18:29',
#    'cs_airline_iata': 'AA',
#    'cs_flight_number': '79',
#    'cs_flight_iata': 'AA79',
#    'status': 'cancelled',
#    'duration': 630,
#    'delayed': 2645,
#    'dep_delayed': 2645,
#    'arr_delayed': 2644,
#    'aircraft_icao': None,
#    'arr_time_ts': 1766615100,
#    'dep_time_ts': 1766577300,
#    'arr_estimated_ts': 1766773740,
#    'dep_estimated_ts': 1766736000}],
#  'terms': "Unauthorized access is prohibited and punishable by law. \nReselling data 'As Is' without AirLabs.Co permission is strictly prohibited. \nFull terms on https://airlabs.co/. \nContact us info@airlabs.co"}

# %%
df2 = pd.DataFrame(data2['response'])
df = pd.concat([df, df2], ignore_index=True)
df.count()
# Out:
# airline_iata         126
# airline_icao         126
# flight_iata          126
# flight_icao          126
# flight_number        126
# dep_iata             126
# dep_icao             126
# dep_terminal          86
# dep_gate              74
# dep_time             126
# dep_time_utc         126
# dep_estimated        126
# dep_estimated_utc    126
# dep_actual            97
# dep_actual_utc        97
# arr_iata             126
# arr_icao             126
# arr_terminal          83
# arr_gate              87
# arr_baggage           74
# arr_time             126
# arr_time_utc         126
# arr_estimated        117
# arr_estimated_utc    117
# arr_actual            30
# arr_actual_utc        30
# cs_airline_iata       78
# cs_flight_number      78
# cs_flight_iata        78
# status               126
# duration             126
# delayed              126
# dep_delayed          123
# arr_delayed          117
# aircraft_icao         22
# arr_time_ts          126
# dep_time_ts          126
# arr_estimated_ts     117
# dep_estimated_ts     126
# arr_actual_ts         30
# dep_actual_ts         97
# dtype: int64

# %%
AIRPORTS = [
    # North America
    ["KJFK","KLAX","KORD","KDEN","KSFO","KSEA","KATL","KDFW","KMSP"],
    # Canada
    ["CYYZ","CYVR","CYUL"],
    # Europe
    ["EGLL","LFPG","EDDF","EHAM","EDDM","LSZH","LEMD","ENGM","LTFM"],
    # Middle East
    ["OMDB","OTHH","OERK","OEJN","OMAA","OKBK","OBBI"],
    # East & SE Asia
    ["RJTT","RJAA","RKSI","ZSPD","ZBAA","ZGGG","VHHH","WSSS","VTBS"],
    # Tropics
    ["KMIA","MMUN","RPLL","WIII"]
]


DELAYS = [30, 45, 60, 90, 120]
OUTPUT_CSV = "airlabs_delays_raw.csv"

API_URL_Delay = "https://airlabs.co/api/v9/delays"
API_URL_Flights = "https://airlabs.co/api/v9/flights"

for delay in DELAYS:
    for airport in AIRPORTS:
      params_delay = {
          "api_key": API_KEY,
          "delay": delay, # maximum delay in minutes
          "type": "departures",
          "dep_icao": ",".join(airport),
          "max": 100,
      }
      params_flights = {
          "api_key": API_KEY,
          "dep_icao": ",".join(airport),
      }


      # step 1: get delays  
      response = requests.get(API_URL_Delay, params=params_delay)
      data = response.json()
      df_delay = pd.DataFrame(data['response'])

      # step 2: get flights
      response_flights = requests.get(API_URL_Flights, params=params_flights)
      data_flights = response_flights.json()
      df_flights = pd.DataFrame(data_flights['response'])

      # step 3: build fligh id to join on


      df = pd.concat([df, df_delay], ignore_index=True)
      print(f"Collected {df_delay.shape[0]} records for delay {delay} at airports {', '.join(airport)}.")
# Out:
# Collected 100 records for delay 45 at KJFK
# Collected 100 records for delay 45 at KLAX
# Collected 100 records for delay 45 at KORD
# Collected 100 records for delay 45 at EGLL
# Collected 100 records for delay 45 at LFPG
# Collected 100 records for delay 45 at EDDF
# Collected 100 records for delay 45 at YSSY
# Collected 100 records for delay 45 at YMML
# Collected 100 records for delay 45 at YBBN
# Collected 100 records for delay 45 at OMDB
# Collected 100 records for delay 45 at OTHH
# Collected 100 records for delay 45 at OERK
# Collected 100 records for delay 45 at RJTT
# Collected 100 records for delay 45 at RKSI
# Collected 100 records for delay 45 at ZSPD
# Collected 100 records for delay 60 at KJFK
# Collected 100 records for delay 60 at KLAX
# Collected 100 records for delay 60 at KORD
# Collected 100 records for delay 60 at EGLL
# Collected 100 records for delay 60 at LFPG
# Collected 100 records for delay 60 at EDDF
# Collected 100 records for delay 60 at YSSY
# Collected 100 records for delay 60 at YMML
# Collected 100 records for delay 60 at YBBN
# Collected 100 records for delay 60 at OMDB
# Collected 100 records for delay 60 at OTHH
# Collected 100 records for delay 60 at OERK
# Collected 100 records for delay 60 at RJTT
# Collected 100 records for delay 60 at RKSI
# Collected 100 records for delay 60 at ZSPD
# Collected 100 records for delay 90 at KJFK
# Collected 100 records for delay 90 at KLAX
# Collected 100 records for delay 90 at KORD
# Collected 100 records for delay 90 at EGLL
# Collected 100 records for delay 90 at LFPG
# Collected 100 records for delay 90 at EDDF
# Collected 100 records for delay 90 at YSSY
# Collected 100 records for delay 90 at YMML
# Collected 100 records for delay 90 at YBBN
# Collected 100 records for delay 90 at OMDB
# Collected 100 records for delay 90 at OTHH
# Collected 100 records for delay 90 at OERK
# Collected 100 records for delay 90 at RJTT
# Collected 100 records for delay 90 at RKSI
# Collected 100 records for delay 90 at ZSPD
# Collected 99 records for delay 120 at KJFK
# Collected 99 records for delay 120 at KLAX
# Collected 99 records for delay 120 at KORD
# Collected 99 records for delay 120 at EGLL
# Collected 99 records for delay 120 at LFPG
# Collected 99 records for delay 120 at EDDF
# Collected 99 records for delay 120 at YSSY
# Collected 99 records for delay 120 at YMML
# Collected 99 records for delay 120 at YBBN
# Collected 99 records for delay 120 at OMDB
# Collected 99 records for delay 120 at OTHH
# Collected 99 records for delay 120 at OERK
# Collected 99 records for delay 120 at RJTT
# Collected 99 records for delay 120 at RKSI
# Collected 99 records for delay 120 at ZSPD

# %%
df.to_csv(OUTPUT_CSV, index=False)

# %% [markdown]
# Now let's explore the aggregated data.

# %%
import pandas as pd
OUTPUT_CSV = "airlabs_delays_raw.csv"
df = pd.read_csv(OUTPUT_CSV)
df.head()
# Out:
#   airline_iata airline_icao flight_iata flight_icao  flight_number dep_iata  \
# 0           JQ          JST      JQ8993     JST8993           8993      BNE
# 1           AA          AAL      AA1208     AAL1208           1208      ONT
# 2           F8          FLE       F8759      FLE759            759      YEG
# 3           KL          KLM      KL9604     KLM9604           9604      YYC
# 4           U6          SVR      U62448     SVR2448           2448      OSS
#
#   dep_icao dep_terminal dep_gate          dep_time  ... delayed dep_delayed  \
# 0     YBBN          NaN      NaN  2025-12-25 10:00  ...      68        63.0
# 1     KONT            4      408  2025-12-24 11:54  ...     310       310.0
# 2     CYEG          NaN        8  2025-12-24 17:50  ...      65        14.0
# 3     CYYC          NaN       A1  2025-12-24 16:00  ...     157       124.0
# 4     UCFO          NaN      NaN  2025-12-25 03:30  ...     204       214.0
#
#   arr_delayed aircraft_icao arr_time_ts dep_time_ts arr_estimated_ts  \
# 0        68.0           NaN  1766626500  1766620800     1.766631e+09
# 1       296.0           NaN  1766609100  1766606040     1.766627e+09
# 2        65.0          B38M  1766628900  1766623800     1.766633e+09
# 3       157.0           NaN  1766623500  1766617200     1.766633e+09
# 4       204.0          A321  1766628600  1766611800     1.766641e+09
#
#   dep_estimated_ts arr_actual_ts dep_actual_ts
# 0       1766624580  1.766631e+09  1.766625e+09
# 1       1766624640  1.766627e+09  1.766625e+09
# 2       1766624640           NaN  1.766625e+09
# 3       1766624640           NaN  1.766625e+09
# 4       1766624640           NaN  1.766625e+09
#
# [5 rows x 41 columns]

# %%
hours = df.describe()['delayed'] / 60
df_exp = pd.concat([df.describe(), pd.DataFrame(hours)], axis=1)
df_exp.head()
# Out:
#        flight_number  cs_flight_number     duration      delayed  dep_delayed  \
# count    6111.000000       4158.000000  6066.000000  6111.000000  6108.000000
# mean     4383.618720       1862.713083   265.957798   240.368352   243.131631
# std      3001.914933       2125.519320   202.400670   378.591340   379.521380
# min        13.000000         13.000000    47.000000    48.000000    14.000000
# 25%      2030.000000        247.000000   101.000000    99.000000    92.000000
#
#        arr_delayed   arr_time_ts   dep_time_ts  arr_estimated_ts  \
# count  5517.000000  6.111000e+03  6.111000e+03      5.532000e+03
# mean    234.995106  1.766640e+09  1.766623e+09      1.766653e+09
# std     390.767028  1.557719e+04  1.191508e+04      2.620949e+04
# min      48.000000  1.766536e+09  1.766492e+09      1.766627e+09
# 25%      94.000000  1.766629e+09  1.766620e+09      1.766638e+09
#
#        dep_estimated_ts  arr_actual_ts  dep_actual_ts     delayed
# count      6.111000e+03   7.500000e+02   3.757000e+03  101.850000
# mean       1.766638e+09   1.766634e+09   1.766631e+09    4.006139
# std        1.776539e+04   1.094450e+03   2.137851e+03    6.309856
# min        1.766625e+09   1.766621e+09   1.766625e+09    0.800000
# 25%        1.766630e+09   1.766634e+09   1.766629e+09    1.650000

# %% [markdown]
# We can See that the average delay time is around 4 hours, so we need to reduce the bias by adding data with no delay.

# %%
import requests
import pandas as pd
from dotenv import load_dotenv
import os

load_dotenv()


API_URL = os.getenv("API_URL")
API_KEY = os.getenv("API_KEY")

params = {
    "api_key": API_KEY,
}

API_URL = f"{API_URL}"

response = requests.get(API_URL, params=params)

data = response.json()
data
# Out:
# {'request': {'lang': 'en',
#   'currency': 'USD',
#   'time': 23,
#   'id': 'l2dxr51xyk0',
#   'server': 'a',
#   'host': 'airlabs.co',
#   'pid': 186134,
#   'key': {'id': 37729,
#    'api_key': '2f1914c4-fa35-4b93-9894-de62a5d49aa7',
#    'type': 'free',
#    'expired': '2026-01-25T00:00:00.000Z',
#    'registered': '2025-12-25T02:41:57.000Z',
#    'upgraded': None,
#    'limits_by_hour': 2500,
#    'limits_by_minute': 250,
#    'limits_by_month': 1000,
#    'limits_total': 1000},
#   'params': {'lang': 'en'},
#   'version': 9,
#   'method': 'flights',
#   'client': {'ip': '2607:fb91:4b0c:a7e3:352c:2adb:7af2:fa5d',
#    'geo': {'country_code': 'US',
#     'country': 'United States',
#     'continent': 'North America',
#     'lat': 37.751,
#     'lng': -97.822,
#     'timezone': 'America/Chicago'},
#    'connection': {},
#    'device': {},
#    'agent': {},
#    'karma': {'is_blocked': False,
#     'is_crawler': False,
#     'is_bot': False,
#     'is_friend': False,
#     'is_regular': True}}},
#  'response': [{'hex': '801623',
#    'reg_number': 'VT-BXH',
#    'flag': 'IN',
#    'lat': 27.486575,
#    'lng': 80.627163,
#    'alt': 12638,
#    'dir': 284.2,
#    'speed': 646,
#    'v_speed': 0,
#    'flight_number': '1082',
#    'flight_icao': 'AXB1082',
#    'flight_iata': 'IX1082',
#    'dep_icao': 'VEBD',
#    'dep_iata': 'IXB',
#    'arr_icao': 'VIDP',
#    'arr_iata': 'DEL',
#    'airline_icao': 'AXB',
#    'airline_iata': 'IX',
#    'aircraft_icao': 'B38M',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'A1E4E9',
#    'reg_number': 'N221BZ',
#    'flag': 'US',
#    'lat': 34.536468,
#    'lng': -79.518339,
#    'alt': 10375,
#    'dir': 31.4,
#    'speed': 745,
#    'v_speed': 0,
#    'flight_number': '537',
#    'flight_icao': 'MXY537',
#    'flight_iata': 'MX537',
#    'dep_icao': 'KRSW',
#    'dep_iata': 'RSW',
#    'arr_icao': 'KBDL',
#    'arr_iata': 'BDL',
#    'airline_icao': 'MXY',
#    'airline_iata': 'MX',
#    'aircraft_icao': 'BCS3',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '740736',
#    'reg_number': 'JY-AYV',
#    'flag': 'JO',
#    'lat': 31.708117,
#    'lng': 36.116131,
#    'alt': 1648,
#    'dir': 155.3,
#    'speed': 483,
#    'v_speed': 0,
#    'flight_number': '144',
#    'flight_icao': 'RJA144',
#    'flight_iata': 'RJ144',
#    'dep_icao': 'ESSA',
#    'dep_iata': 'ARN',
#    'arr_icao': 'OJAI',
#    'arr_iata': 'AMM',
#    'airline_icao': 'RJA',
#    'airline_iata': 'RJ',
#    'aircraft_icao': 'A321',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'A3549D',
#    'reg_number': 'N3132J',
#    'flag': 'US',
#    'lat': 30.491278,
#    'lng': -81.395163,
#    'alt': 10444,
#    'dir': 358.4,
#    'speed': 745,
#    'v_speed': 0,
#    'flight_number': '2424',
#    'flight_icao': 'JBU2424',
#    'flight_iata': 'B62424',
#    'dep_icao': 'KMCO',
#    'dep_iata': 'MCO',
#    'arr_icao': 'KDCA',
#    'arr_iata': 'DCA',
#    'airline_icao': 'JBU',
#    'airline_iata': 'B6',
#    'aircraft_icao': 'BCS3',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '511171',
#    'reg_number': 'ES-MBB',
#    'flag': 'EE',
#    'lat': 46.955505,
#    'lng': -0.493553,
#    'alt': 11602,
#    'dir': 44,
#    'speed': 813,
#    'v_speed': 0,
#    'flight_number': '6519',
#    'flight_icao': 'MBU6519',
#    'flight_iata': 'DI6519',
#    'dep_icao': 'GCFV',
#    'dep_iata': 'FUE',
#    'arr_icao': 'EDDP',
#    'arr_iata': 'LEJ',
#    'airline_icao': 'MBU',
#    'airline_iata': 'DI',
#    'aircraft_icao': 'A20N',
#    'updated': 1766679580,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '740734',
#    'reg_number': 'JY-AYT',
#    'flag': 'JO',
#    'lat': 27.062202,
#    'lng': 49.646228,
#    'alt': 10954,
#    'dir': 94,
#    'speed': 933,
#    'v_speed': 0,
#    'flight_number': '614',
#    'flight_icao': 'RJA614',
#    'flight_iata': 'RJ614',
#    'dep_icao': 'OJAI',
#    'dep_iata': 'AMM',
#    'arr_icao': 'OMDB',
#    'arr_iata': 'DXB',
#    'airline_icao': 'RJA',
#    'airline_iata': 'RJ',
#    'aircraft_icao': 'A321',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '740737',
#    'flag': 'JO',
#    'lat': 44.088333,
#    'lng': 14.896493,
#    'alt': 11297,
#    'dir': 129,
#    'speed': 838,
#    'v_speed': 0,
#    'flight_number': '142',
#    'flight_icao': 'RJA142',
#    'flight_iata': 'RJ142',
#    'dep_icao': 'EBBR',
#    'dep_iata': 'BRU',
#    'arr_icao': 'OJAI',
#    'arr_iata': 'AMM',
#    'airline_icao': 'RJA',
#    'airline_iata': 'RJ',
#    'aircraft_icao': 'A20N',
#    'updated': 1766679580,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '740826',
#    'reg_number': 'JY-BAF',
#    'flag': 'JO',
#    'lat': 62.688935,
#    'lng': -25.951415,
#    'alt': 11792,
#    'dir': 282.3,
#    'speed': 895,
#    'v_speed': 0,
#    'flight_number': '261',
#    'flight_icao': 'RJA261',
#    'flight_iata': 'RJ261',
#    'dep_icao': 'OJAI',
#    'dep_iata': 'AMM',
#    'arr_icao': 'KJFK',
#    'arr_iata': 'JFK',
#    'airline_icao': 'RJA',
#    'airline_iata': 'RJ',
#    'aircraft_icao': 'B788',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '801503',
#    'reg_number': 'VT-IPC',
#    'flag': 'IN',
#    'lat': 13.880063,
#    'lng': 73.62349,
#    'alt': 11610,
#    'dir': 350.8,
#    'speed': 843,
#    'v_speed': 0,
#    'flight_number': '1132',
#    'flight_icao': 'IGO1132',
#    'flight_iata': '6E1132',
#    'dep_icao': 'VRMM',
#    'dep_iata': 'MLE',
#    'arr_icao': 'VABB',
#    'arr_iata': 'BOM',
#    'airline_icao': 'IGO',
#    'airline_iata': '6E',
#    'aircraft_icao': 'A20N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '801607',
#    'reg_number': 'VT-BXD',
#    'flag': 'IN',
#    'lat': 28.376818,
#    'lng': 76.766585,
#    'alt': 3736,
#    'dir': 197.6,
#    'speed': 552,
#    'v_speed': 0,
#    'flight_number': '1180',
#    'flight_icao': 'AXB1180',
#    'flight_iata': 'IX1180',
#    'dep_icao': 'VEBD',
#    'dep_iata': 'IXB',
#    'arr_icao': 'VIDP',
#    'arr_iata': 'DEL',
#    'airline_icao': 'AXB',
#    'airline_iata': 'IX',
#    'aircraft_icao': 'B38M',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '896411',
#    'reg_number': 'A6-AOE',
#    'flag': 'AE',
#    'lat': 30.420354,
#    'lng': 51.426033,
#    'alt': 11526,
#    'dir': 151.6,
#    'speed': 882,
#    'v_speed': 0,
#    'flight_number': '606',
#    'flight_icao': 'ABY606',
#    'flight_iata': 'G9606',
#    'dep_icao': 'EPWA',
#    'dep_iata': 'WAW',
#    'arr_icao': 'OMSJ',
#    'arr_iata': 'SHJ',
#    'airline_icao': 'ABY',
#    'airline_iata': 'G9',
#    'aircraft_icao': 'A320',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '4CAE18',
#    'reg_number': 'EI-HXB',
#    'flag': 'IT',
#    'lat': 33.440534,
#    'lng': 25.047622,
#    'alt': 10688,
#    'dir': 139,
#    'speed': 936,
#    'v_speed': 0,
#    'flight_number': '838',
#    'flight_icao': 'ITY838',
#    'flight_iata': 'AZ838',
#    'dep_icao': 'LIRF',
#    'dep_iata': 'FCO',
#    'arr_icao': 'OERK',
#    'arr_iata': 'RUH',
#    'airline_icao': 'ITY',
#    'airline_iata': 'AZ',
#    'aircraft_icao': 'A21N',
#    'updated': 1766679580,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '75025E',
#    'reg_number': '9M-MTK',
#    'flag': 'MY',
#    'lat': -4.955556,
#    'lng': 108.37705,
#    'alt': 12074,
#    'dir': 157.8,
#    'speed': 860,
#    'v_speed': 0,
#    'flight_number': '139',
#    'flight_icao': 'MAS139',
#    'flight_iata': 'MH139',
#    'dep_icao': 'WMKK',
#    'dep_iata': 'KUL',
#    'arr_icao': 'YPAD',
#    'arr_iata': 'ADL',
#    'airline_icao': 'MAS',
#    'airline_iata': 'MH',
#    'aircraft_icao': 'A333',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '6832A3',
#    'reg_number': 'UP-B3742',
#    'flag': 'KZ',
#    'lat': 42.267482,
#    'lng': 69.975991,
#    'alt': 5300,
#    'dir': 157,
#    'speed': 673,
#    'v_speed': 0,
#    'flight_number': '469',
#    'flight_icao': 'VSV469',
#    'flight_iata': 'DV469',
#    'dep_icao': 'UAII',
#    'dep_iata': 'CIT',
#    'arr_icao': 'VTBS',
#    'arr_iata': 'BKK',
#    'airline_icao': 'VSV',
#    'airline_iata': 'DV',
#    'aircraft_icao': 'B38M',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '440CAB',
#    'reg_number': 'OE-LZN',
#    'flag': 'AT',
#    'lat': 49.897941,
#    'lng': 10.285557,
#    'alt': 11267,
#    'dir': 109,
#    'speed': 744,
#    'v_speed': 0,
#    'flight_number': '336',
#    'flight_icao': 'AUA336',
#    'flight_iata': 'OS336',
#    'dep_icao': 'EGLL',
#    'dep_iata': 'LHR',
#    'arr_icao': 'LOWW',
#    'arr_iata': 'VIE',
#    'airline_icao': 'AUA',
#    'airline_iata': 'OS',
#    'aircraft_icao': 'A20N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'A358BD',
#    'reg_number': 'N3145J',
#    'flag': 'US',
#    'lat': 33.258738,
#    'lng': -76.740975,
#    'alt': 10992,
#    'dir': 198,
#    'speed': 964,
#    'v_speed': 0,
#    'flight_number': '121',
#    'flight_icao': 'JBU121',
#    'flight_iata': 'B6121',
#    'dep_icao': 'KJFK',
#    'dep_iata': 'JFK',
#    'arr_icao': 'MYNN',
#    'arr_iata': 'NAS',
#    'airline_icao': 'JBU',
#    'airline_iata': 'B6',
#    'aircraft_icao': 'BCS3',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'A55FA2',
#    'reg_number': 'N44501',
#    'flag': 'US',
#    'lat': 42.197693,
#    'lng': -78.101858,
#    'alt': 10383,
#    'dir': 291,
#    'speed': 625,
#    'v_speed': 0,
#    'flight_number': '1525',
#    'flight_icao': 'UAL1525',
#    'flight_iata': 'UA1525',
#    'dep_icao': 'KEWR',
#    'dep_iata': 'EWR',
#    'arr_icao': 'KORD',
#    'arr_iata': 'ORD',
#    'airline_icao': 'UAL',
#    'airline_iata': 'UA',
#    'aircraft_icao': 'A21N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'A24508',
#    'reg_number': 'N24505',
#    'flag': 'US',
#    'lat': 39.249304,
#    'lng': -78.296018,
#    'alt': 3515,
#    'dir': 122.8,
#    'speed': 742,
#    'v_speed': 0,
#    'flight_number': '482',
#    'flight_icao': 'UAL482',
#    'flight_iata': 'UA482',
#    'dep_icao': 'KORD',
#    'dep_iata': 'ORD',
#    'arr_icao': 'KIAD',
#    'arr_iata': 'IAD',
#    'airline_icao': 'UAL',
#    'airline_iata': 'UA',
#    'aircraft_icao': 'A21N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'C05EE5',
#    'reg_number': 'C-GJYI',
#    'flag': 'CA',
#    'lat': 42.81607,
#    'lng': -85.229825,
#    'alt': 8722,
#    'dir': 262.7,
#    'speed': 715,
#    'v_speed': 0,
#    'flight_number': '521',
#    'flight_icao': 'ACA521',
#    'flight_iata': 'AC521',
#    'dep_icao': 'CYUL',
#    'dep_iata': 'YUL',
#    'arr_icao': 'KORD',
#    'arr_iata': 'ORD',
#    'airline_icao': 'ACA',
#    'airline_iata': 'AC',
#    'aircraft_icao': 'BCS3',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'A8D5A4',
#    'reg_number': 'N66897',
#    'flag': 'US',
#    'lat': 37.067475,
#    'lng': -84.312184,
#    'alt': 11023,
#    'dir': 73.7,
#    'speed': 855,
#    'v_speed': 0,
#    'flight_number': '1449',
#    'flight_icao': 'UAL1449',
#    'flight_iata': 'UA1449',
#    'dep_icao': 'KAUS',
#    'dep_iata': 'AUS',
#    'arr_icao': 'KEWR',
#    'arr_iata': 'EWR',
#    'airline_icao': 'UAL',
#    'airline_iata': 'UA',
#    'aircraft_icao': 'B739',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'A8CF70',
#    'reg_number': 'N667NK',
#    'flag': 'US',
#    'lat': 40.339153,
#    'lng': -99.924185,
#    'alt': 9529,
#    'dir': 256.3,
#    'speed': 790,
#    'v_speed': 0,
#    'flight_number': '1451',
#    'flight_icao': 'NKS1451',
#    'flight_iata': 'NK1451',
#    'dep_icao': 'KDTW',
#    'dep_iata': 'DTW',
#    'arr_icao': 'KLAS',
#    'arr_iata': 'LAS',
#    'airline_icao': 'NKS',
#    'airline_iata': 'NK',
#    'aircraft_icao': 'A321',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'C02F21',
#    'reg_number': 'C-FRWA',
#    'flag': 'CA',
#    'lat': 44.657306,
#    'lng': -110.454924,
#    'alt': 10688,
#    'dir': 167.9,
#    'speed': 646,
#    'v_speed': 0,
#    'flight_number': '2112',
#    'flight_icao': 'WJA2112',
#    'flight_iata': 'WS2112',
#    'dep_icao': 'CYEG',
#    'dep_iata': 'YEG',
#    'arr_icao': 'MMPR',
#    'arr_iata': 'PVR',
#    'airline_icao': 'WJA',
#    'airline_iata': 'WS',
#    'aircraft_icao': 'B738',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'A19D59',
#    'reg_number': 'N203BZ',
#    'flag': 'US',
#    'lat': 33.847014,
#    'lng': -112.170506,
#    'alt': 3195,
#    'dir': 189,
#    'speed': 492,
#    'v_speed': 0,
#    'flight_number': '854',
#    'flight_icao': 'MXY854',
#    'flight_iata': 'MX854',
#    'dep_icao': 'KRDU',
#    'dep_iata': 'RDU',
#    'arr_icao': 'KALB',
#    'arr_iata': 'ALB',
#    'airline_icao': 'MXY',
#    'airline_iata': 'MX',
#    'aircraft_icao': 'BCS3',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '4D248E',
#    'reg_number': '9H-WDH',
#    'flag': 'MT',
#    'lat': 43.905026,
#    'lng': 16.633877,
#    'alt': 9895,
#    'dir': 268,
#    'speed': 809,
#    'v_speed': 0,
#    'flight_number': '5159',
#    'flight_icao': 'WMT5159',
#    'flight_iata': 'W45159',
#    'dep_icao': 'LQSA',
#    'dep_iata': 'SJJ',
#    'arr_icao': 'LIRF',
#    'arr_iata': 'FCO',
#    'airline_icao': 'WMT',
#    'airline_iata': 'W4',
#    'aircraft_icao': 'A21N',
#    'updated': 1766679580,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '342090',
#    'reg_number': 'EC-ILR',
#    'flag': 'ES',
#    'lat': 46.193303,
#    'lng': -3.885467,
#    'alt': 10809,
#    'dir': 2,
#    'speed': 861,
#    'v_speed': 0,
#    'flight_number': '1893',
#    'flight_icao': 'IBE1893',
#    'flight_iata': 'IB1893',
#    'dep_icao': 'LEMD',
#    'dep_iata': 'MAD',
#    'arr_icao': 'EGCC',
#    'arr_iata': 'MAN',
#    'airline_icao': 'IBS',
#    'airline_iata': 'I2',
#    'aircraft_icao': 'A320',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '758533',
#    'reg_number': 'RP-C4114',
#    'flag': 'PH',
#    'lat': 13.353178,
#    'lng': 121.548414,
#    'alt': 6504,
#    'dir': 326.6,
#    'speed': 734,
#    'v_speed': 0,
#    'flight_number': '686',
#    'flight_icao': 'CEB686',
#    'flight_iata': '5J686',
#    'dep_icao': 'RPSP',
#    'dep_iata': 'TAG',
#    'arr_icao': 'RPLL',
#    'arr_iata': 'MNL',
#    'airline_icao': 'CEB',
#    'airline_iata': '5J',
#    'aircraft_icao': 'A321',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '781038',
#    'reg_number': 'B-8642',
#    'flag': 'CN',
#    'lat': 22.652671,
#    'lng': 108.205537,
#    'alt': 9682,
#    'dir': 312.7,
#    'speed': 721,
#    'v_speed': 0,
#    'flight_number': '6214',
#    'flight_icao': 'CHB6214',
#    'flight_iata': 'PN6214',
#    'dep_icao': 'ZJSY',
#    'dep_iata': 'SYX',
#    'arr_icao': 'ZUCK',
#    'arr_iata': 'CKG',
#    'airline_icao': 'CHB',
#    'airline_iata': 'PN',
#    'aircraft_icao': 'A320',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '789270',
#    'reg_number': 'B-KJC',
#    'flag': 'CN',
#    'lat': 21.185122,
#    'lng': 112.520296,
#    'alt': 11328,
#    'dir': 71.6,
#    'speed': 964,
#    'v_speed': 0,
#    'flight_number': '2296',
#    'flight_icao': 'HGB2296',
#    'flight_iata': 'HB2296',
#    'dep_icao': 'VTBS',
#    'dep_iata': 'BKK',
#    'arr_icao': 'VHHH',
#    'arr_iata': 'HKG',
#    'airline_icao': 'HGB',
#    'airline_iata': 'HB',
#    'aircraft_icao': 'B738',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '789271',
#    'reg_number': 'B-KKA',
#    'flag': 'HK',
#    'lat': 32.71083,
#    'lng': 133.436053,
#    'alt': 9750,
#    'dir': 242,
#    'speed': 670,
#    'v_speed': 0,
#    'flight_number': '623',
#    'flight_icao': 'HKE623',
#    'flight_iata': 'UO623',
#    'dep_icao': 'RJTT',
#    'dep_iata': 'HND',
#    'arr_icao': 'VHHH',
#    'arr_iata': 'HKG',
#    'airline_icao': 'HKE',
#    'airline_iata': 'UO',
#    'aircraft_icao': 'A21N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '800739',
#    'reg_number': 'VT-ANS',
#    'flag': 'IN',
#    'lat': 48.362848,
#    'lng': 19.860735,
#    'alt': 12151,
#    'dir': 310,
#    'speed': 918,
#    'v_speed': 0,
#    'flight_number': '155',
#    'flight_icao': 'AIC155',
#    'flight_iata': 'AI155',
#    'dep_icao': 'VIDP',
#    'dep_iata': 'DEL',
#    'arr_icao': 'EHAM',
#    'arr_iata': 'AMS',
#    'airline_icao': 'AIC',
#    'airline_iata': 'AI',
#    'aircraft_icao': 'B788',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '801458',
#    'reg_number': 'VT-ISW',
#    'flag': 'IN',
#    'lat': 19.45125,
#    'lng': 73.983878,
#    'alt': 6870,
#    'dir': 254.8,
#    'speed': 611,
#    'v_speed': 0,
#    'flight_number': '2029',
#    'flight_icao': 'IGO2029',
#    'flight_iata': '6E2029',
#    'dep_icao': 'VOGO',
#    'dep_iata': 'GOI',
#    'arr_icao': 'VIDP',
#    'arr_iata': 'DEL',
#    'airline_icao': 'IGO',
#    'airline_iata': '6E',
#    'aircraft_icao': 'A20N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '801499',
#    'reg_number': 'VT-IIM',
#    'flag': 'IN',
#    'lat': 23.033243,
#    'lng': 72.421158,
#    'alt': 939,
#    'dir': 216.1,
#    'speed': 352,
#    'v_speed': 0,
#    'flight_number': '7276',
#    'flight_icao': 'IGO7276',
#    'flight_iata': '6E7276',
#    'dep_icao': 'VIJP',
#    'dep_iata': 'JAI',
#    'arr_icao': 'VAAH',
#    'arr_iata': 'AMD',
#    'airline_icao': 'IGO',
#    'airline_iata': '6E',
#    'aircraft_icao': 'A20N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '801604',
#    'reg_number': 'VT-BXE',
#    'flag': 'IN',
#    'lat': 26.238511,
#    'lng': 90.362582,
#    'alt': 5795,
#    'dir': 106.2,
#    'speed': 771,
#    'v_speed': 0,
#    'flight_number': '1120',
#    'flight_icao': 'AXB1120',
#    'flight_iata': 'IX1120',
#    'dep_icao': 'VIDP',
#    'dep_iata': 'DEL',
#    'arr_icao': 'VEGT',
#    'arr_iata': 'GAU',
#    'airline_icao': 'AXB',
#    'airline_iata': 'IX',
#    'aircraft_icao': 'B38M',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '896178',
#    'reg_number': 'A6-EWF',
#    'flag': 'AE',
#    'lat': 38.078711,
#    'lng': 20.364312,
#    'alt': 11297,
#    'dir': 114,
#    'speed': 1031,
#    'v_speed': 0,
#    'flight_number': '256',
#    'flight_icao': 'UAE256',
#    'flight_iata': 'EK256',
#    'dep_icao': 'MMMX',
#    'dep_iata': 'MEX',
#    'arr_icao': 'LEBL',
#    'arr_iata': 'BCN',
#    'airline_icao': 'UAE',
#    'airline_iata': 'EK',
#    'aircraft_icao': 'B77L',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '896335',
#    'reg_number': 'A6-FED',
#    'flag': 'AE',
#    'lat': 26.19236,
#    'lng': 51.943209,
#    'alt': 10680,
#    'dir': 297.9,
#    'speed': 756,
#    'v_speed': 0,
#    'flight_number': '1301',
#    'flight_icao': 'FDB1301',
#    'flight_iata': 'FZ1301',
#    'dep_icao': 'OMDB',
#    'dep_iata': 'DXB',
#    'arr_icao': 'LLBG',
#    'arr_iata': 'TLV',
#    'airline_icao': 'FDB',
#    'airline_iata': 'FZ',
#    'aircraft_icao': 'B738',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '896496',
#    'reg_number': 'A6-AOP',
#    'flag': 'AE',
#    'lat': 27.158745,
#    'lng': 49.382237,
#    'alt': 10596,
#    'dir': 296,
#    'speed': 729,
#    'v_speed': 0,
#    'flight_number': '387',
#    'flight_icao': 'ABY387',
#    'flight_iata': 'G9387',
#    'dep_icao': 'OMSJ',
#    'dep_iata': 'SHJ',
#    'arr_icao': 'OLBA',
#    'arr_iata': 'BEY',
#    'airline_icao': 'ABY',
#    'airline_iata': 'G9',
#    'aircraft_icao': 'A320',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '896608',
#    'reg_number': 'A6-FKR',
#    'flag': 'AE',
#    'lat': 25.996768,
#    'lng': 52.381489,
#    'alt': 10063,
#    'dir': 297,
#    'speed': 780,
#    'v_speed': 0,
#    'flight_number': '143',
#    'flight_icao': 'FDB143',
#    'flight_iata': 'FZ143',
#    'dep_icao': 'OMDB',
#    'dep_iata': 'DXB',
#    'arr_icao': 'OJAI',
#    'arr_iata': 'AMM',
#    'airline_icao': 'FDB',
#    'airline_iata': 'FZ',
#    'aircraft_icao': 'B38M',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '3472C9',
#    'reg_number': 'EC-NUD',
#    'flag': 'ES',
#    'lat': 40.417717,
#    'lng': -4.318856,
#    'alt': 6336,
#    'dir': 242.9,
#    'speed': 711,
#    'v_speed': 0,
#    'flight_number': '1581',
#    'flight_icao': 'IBS1581',
#    'flight_iata': 'I21581',
#    'dep_icao': 'LEMD',
#    'dep_iata': 'MAD',
#    'arr_icao': 'GCXO',
#    'arr_iata': 'TFN',
#    'airline_icao': 'IBS',
#    'airline_iata': 'I2',
#    'aircraft_icao': 'A21N',
#    'updated': 1766679580,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '39D312',
#    'reg_number': 'F-HUYS',
#    'flag': 'FR',
#    'lat': 51.582173,
#    'lng': 13.239038,
#    'alt': 5277,
#    'dir': 353,
#    'speed': 677,
#    'v_speed': 0,
#    'squawk': '1000',
#    'flight_number': '9865',
#    'flight_icao': 'TVF9865',
#    'flight_iata': 'TO9865',
#    'dep_icao': 'GMMX',
#    'dep_iata': 'RAK',
#    'arr_icao': 'EDDB',
#    'arr_iata': 'BER',
#    'airline_icao': 'TVF',
#    'airline_iata': 'TO',
#    'aircraft_icao': 'B738',
#    'updated': 1766679580,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '44B438',
#    'reg_number': 'OO-MAX',
#    'flag': 'BE',
#    'lat': 49.273613,
#    'lng': 2.768221,
#    'alt': 10497,
#    'dir': 210,
#    'speed': 831,
#    'v_speed': 0,
#    'flight_number': '3453',
#    'flight_icao': 'JAF3453',
#    'flight_iata': 'TB3453',
#    'dep_icao': 'EBBR',
#    'dep_iata': 'BRU',
#    'arr_icao': 'DAOO',
#    'arr_iata': 'ORN',
#    'airline_icao': 'JAF',
#    'airline_iata': 'TB',
#    'aircraft_icao': 'B38M',
#    'updated': 1766679580,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '7503D6',
#    'reg_number': '9M-LCZ',
#    'flag': 'MY',
#    'lat': -24.807645,
#    'lng': 116.780049,
#    'alt': 11907,
#    'dir': 182,
#    'speed': 820,
#    'v_speed': 0,
#    'flight_number': '193',
#    'flight_icao': 'MXD193',
#    'flight_iata': 'OD193',
#    'dep_icao': 'WADD',
#    'dep_iata': 'DPS',
#    'arr_icao': 'YPPH',
#    'arr_iata': 'PER',
#    'airline_icao': 'MXD',
#    'airline_iata': 'OD',
#    'aircraft_icao': 'B738',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'A5FF93',
#    'reg_number': 'N486HA',
#    'flag': 'US',
#    'lat': 21.320757,
#    'lng': -157.904622,
#    'alt': 391,
#    'dir': 133.2,
#    'speed': 295,
#    'v_speed': 0,
#    'flight_number': '1016',
#    'flight_icao': 'ASA1016',
#    'flight_iata': 'AS1016',
#    'dep_icao': 'PHNL',
#    'dep_iata': 'HNL',
#    'arr_icao': 'PHOG',
#    'arr_iata': 'OGG',
#    'airline_icao': 'ASA',
#    'airline_iata': 'AS',
#    'aircraft_icao': 'B712',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '8A0987',
#    'reg_number': 'PK-TLD',
#    'flag': 'ID',
#    'lat': 22.909866,
#    'lng': 113.949842,
#    'alt': 4361,
#    'dir': 353.1,
#    'speed': 469,
#    'v_speed': 0,
#    'flight_number': '969',
#    'flight_icao': 'TNU969',
#    'flight_iata': '8B969',
#    'dep_icao': 'WADD',
#    'dep_iata': 'DPS',
#    'arr_icao': 'ZGGG',
#    'arr_iata': 'CAN',
#    'airline_icao': 'TNU',
#    'airline_iata': '8B',
#    'aircraft_icao': 'A320',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '7585F8',
#    'reg_number': 'RP-C3287',
#    'flag': 'PH',
#    'lat': 13.171443,
#    'lng': 119.969212,
#    'alt': 9331,
#    'dir': 12,
#    'speed': 830,
#    'v_speed': 0,
#    'flight_number': '410',
#    'flight_icao': 'CEB410',
#    'flight_iata': '5J410',
#    'dep_icao': 'WBSB',
#    'dep_iata': 'BWN',
#    'arr_icao': 'RPLL',
#    'arr_iata': 'MNL',
#    'airline_icao': 'CEB',
#    'airline_iata': '5J',
#    'aircraft_icao': 'A20N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '8A06BE',
#    'reg_number': 'PK-CRI',
#    'flag': 'ID',
#    'lat': -6.090215,
#    'lng': 106.774675,
#    'alt': 688,
#    'dir': 247.8,
#    'speed': 266,
#    'v_speed': 0,
#    'flight_number': '273',
#    'flight_icao': 'SJY273',
#    'flight_iata': 'SJ273',
#    'dep_icao': 'WADD',
#    'dep_iata': 'DPS',
#    'arr_icao': 'WIII',
#    'arr_iata': 'CGK',
#    'airline_icao': 'SJY',
#    'airline_iata': 'SJ',
#    'aircraft_icao': 'B738',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '8881B0',
#    'reg_number': 'VN-A544',
#    'flag': 'VN',
#    'lat': 20.036544,
#    'lng': 105.842912,
#    'alt': 7533,
#    'dir': 335.6,
#    'speed': 719,
#    'v_speed': 0,
#    'flight_number': '156',
#    'flight_icao': 'VJC156',
#    'flight_iata': 'VJ156',
#    'dep_icao': 'VVTS',
#    'dep_iata': 'SGN',
#    'arr_icao': 'VVNB',
#    'arr_iata': 'HAN',
#    'airline_icao': 'VJC',
#    'airline_iata': 'VJ',
#    'aircraft_icao': 'A321',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '7585A1',
#    'reg_number': 'RP-C4118',
#    'flag': 'PH',
#    'lat': 10.871676,
#    'lng': 107.048051,
#    'alt': 2075,
#    'dir': 268.1,
#    'speed': 500,
#    'v_speed': 0,
#    'flight_number': '751',
#    'flight_icao': 'CEB751',
#    'flight_iata': '5J751',
#    'dep_icao': 'RPLL',
#    'dep_iata': 'MNL',
#    'arr_icao': 'VVTS',
#    'arr_iata': 'SGN',
#    'airline_icao': 'CEB',
#    'airline_iata': '5J',
#    'aircraft_icao': 'A21N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '7020B4',
#    'reg_number': 'S2-AJH',
#    'flag': 'BD',
#    'lat': 23.810981,
#    'lng': 90.423342,
#    'alt': 345,
#    'dir': 145.4,
#    'speed': 362,
#    'v_speed': 0,
#    'flight_number': '307',
#    'flight_icao': 'UBG307',
#    'flight_iata': 'BS307',
#    'dep_icao': 'VGHS',
#    'dep_iata': 'DAC',
#    'arr_icao': 'WSSS',
#    'arr_iata': 'SIN',
#    'airline_icao': 'UBG',
#    'airline_iata': 'BS',
#    'aircraft_icao': 'B738',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'E071CB',
#    'reg_number': 'LV-GGK',
#    'flag': 'AR',
#    'lat': -35.181084,
#    'lng': -59.927183,
#    'alt': 7830,
#    'dir': 58.9,
#    'speed': 780,
#    'v_speed': 0,
#    'flight_number': '1695',
#    'flight_icao': 'ARG1695',
#    'flight_iata': 'AR1695',
#    'dep_icao': 'SAZS',
#    'dep_iata': 'BRC',
#    'arr_icao': 'SABE',
#    'arr_iata': 'AEP',
#    'airline_icao': 'ARG',
#    'airline_iata': 'AR',
#    'aircraft_icao': 'B738',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'E03086',
#    'reg_number': 'LV-CBF',
#    'flag': 'AR',
#    'lat': -35.068593,
#    'lng': -59.072539,
#    'alt': 8722,
#    'dir': 226.6,
#    'speed': 746,
#    'v_speed': 0,
#    'flight_number': '1656',
#    'flight_icao': 'ARG1656',
#    'flight_iata': 'AR1656',
#    'dep_icao': 'SABE',
#    'dep_iata': 'AEP',
#    'arr_icao': 'SAZY',
#    'arr_iata': 'CPC',
#    'airline_icao': 'ARG',
#    'airline_iata': 'AR',
#    'aircraft_icao': 'B737',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'E4943F',
#    'reg_number': 'PR-XMC',
#    'flag': 'BR',
#    'lat': -33.880365,
#    'lng': -54.949016,
#    'alt': 8988,
#    'dir': 41,
#    'speed': 829,
#    'v_speed': 0,
#    'flight_number': '7631',
#    'flight_icao': 'GLO7631',
#    'flight_iata': 'G37631',
#    'dep_icao': 'SUMU',
#    'dep_iata': 'MVD',
#    'arr_icao': 'SBGR',
#    'arr_iata': 'GRU',
#    'airline_icao': 'GLO',
#    'airline_iata': 'G3',
#    'aircraft_icao': 'B38M',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'E80620',
#    'reg_number': 'CC-DIC',
#    'flag': 'CL',
#    'lat': -32.216376,
#    'lng': -54.055773,
#    'alt': 11335,
#    'dir': 50.4,
#    'speed': 902,
#    'v_speed': 0,
#    'flight_number': '3810',
#    'flight_icao': 'JAT3810',
#    'flight_iata': 'JA3810',
#    'dep_icao': 'SAEZ',
#    'dep_iata': 'EZE',
#    'arr_icao': 'SBGL',
#    'arr_iata': 'GIG',
#    'airline_icao': 'JES',
#    'airline_iata': 'WJ',
#    'aircraft_icao': 'A21N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'E48B65',
#    'reg_number': 'PR-MYP',
#    'flag': 'CL',
#    'lat': -26.751029,
#    'lng': -48.638346,
#    'alt': 3301,
#    'dir': 234.7,
#    'speed': 479,
#    'v_speed': 0,
#    'flight_number': '4608',
#    'flight_icao': 'LAN4608',
#    'flight_iata': 'LA4608',
#    'dep_icao': 'SBGR',
#    'dep_iata': 'GRU',
#    'arr_icao': 'SBNF',
#    'arr_iata': 'NVT',
#    'airline_icao': 'TAM',
#    'airline_iata': 'JJ',
#    'aircraft_icao': 'A320',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'E49A86',
#    'reg_number': 'PS-AEK',
#    'flag': 'BR',
#    'lat': -21.031085,
#    'lng': -48.430305,
#    'alt': 11815,
#    'dir': 325.4,
#    'speed': 852,
#    'v_speed': 0,
#    'flight_number': '4216',
#    'flight_icao': 'AZU4216',
#    'flight_iata': 'AD4216',
#    'dep_icao': 'SBKP',
#    'dep_iata': 'VCP',
#    'arr_icao': 'SBAT',
#    'arr_iata': 'AFL',
#    'airline_icao': 'AZU',
#    'airline_iata': 'AD',
#    'aircraft_icao': 'E295',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'E48DC5',
#    'reg_number': 'PT-MXJ',
#    'flag': 'CL',
#    'lat': -23.34478,
#    'lng': -46.727217,
#    'alt': 2661,
#    'dir': 315.6,
#    'speed': 533,
#    'v_speed': 0,
#    'flight_number': '3230',
#    'flight_icao': 'LAN3230',
#    'flight_iata': 'LA3230',
#    'dep_icao': 'SBGR',
#    'dep_iata': 'GRU',
#    'arr_icao': 'SBBE',
#    'arr_iata': 'BEL',
#    'airline_icao': 'TAM',
#    'airline_iata': 'JJ',
#    'aircraft_icao': 'A321',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'E483DD',
#    'reg_number': 'PT-TMA',
#    'flag': 'CL',
#    'lat': -23.09891,
#    'lng': -43.988305,
#    'alt': 4094,
#    'dir': 70,
#    'speed': 633,
#    'v_speed': 0,
#    'flight_number': '3532',
#    'flight_icao': 'LAN3532',
#    'flight_iata': 'LA3532',
#    'dep_icao': 'SBSP',
#    'dep_iata': 'CGH',
#    'arr_icao': 'SBRJ',
#    'arr_iata': 'SDU',
#    'airline_icao': 'TAM',
#    'airline_iata': 'JJ',
#    'aircraft_icao': 'A319',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'E4950E',
#    'reg_number': 'PR-XMJ',
#    'flag': 'BR',
#    'lat': -14.641237,
#    'lng': -39.785011,
#    'alt': 12585,
#    'dir': 38,
#    'speed': 781,
#    'v_speed': 0,
#    'flight_number': '1987',
#    'flight_icao': 'GLO1987',
#    'flight_iata': 'G31987',
#    'dep_icao': 'SBKP',
#    'dep_iata': 'VCP',
#    'arr_icao': 'SBSV',
#    'arr_iata': 'SSA',
#    'airline_icao': 'GLO',
#    'airline_iata': 'G3',
#    'aircraft_icao': 'B38M',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'E4943E',
#    'reg_number': 'PR-XMD',
#    'flag': 'BR',
#    'lat': -4.596828,
#    'lng': -39.082323,
#    'alt': 5818,
#    'dir': 25.5,
#    'speed': 697,
#    'v_speed': 0,
#    'flight_number': '1389',
#    'flight_icao': 'GLO1389',
#    'flight_iata': 'G31389',
#    'dep_icao': 'SBSP',
#    'dep_iata': 'CGH',
#    'arr_icao': 'SBFZ',
#    'arr_iata': 'FOR',
#    'airline_icao': 'GLO',
#    'airline_iata': 'G3',
#    'aircraft_icao': 'B38M',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'E49890',
#    'reg_number': 'PS-GPH',
#    'flag': 'BR',
#    'lat': -12.712042,
#    'lng': -38.990708,
#    'alt': 11015,
#    'dir': 221.3,
#    'speed': 850,
#    'v_speed': 0,
#    'flight_number': '1809',
#    'flight_icao': 'GLO1809',
#    'flight_iata': 'G31809',
#    'dep_icao': 'SBRF',
#    'dep_iata': 'REC',
#    'arr_icao': 'SBSP',
#    'arr_iata': 'CGH',
#    'airline_icao': 'GLO',
#    'airline_iata': 'G3',
#    'aircraft_icao': 'B38M',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'E49311',
#    'reg_number': 'PR-YRH',
#    'flag': 'BR',
#    'lat': -14.712758,
#    'lng': -38.681626,
#    'alt': 11907,
#    'dir': 28.4,
#    'speed': 781,
#    'v_speed': 0,
#    'flight_number': '2641',
#    'flight_icao': 'AZU2641',
#    'flight_iata': 'AD2641',
#    'dep_icao': 'SBGL',
#    'dep_iata': 'GIG',
#    'arr_icao': 'SBRF',
#    'arr_iata': 'REC',
#    'airline_icao': 'AZU',
#    'airline_iata': 'AD',
#    'aircraft_icao': 'A20N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'E4967F',
#    'reg_number': 'PS-AEI',
#    'flag': 'BR',
#    'lat': -13.068523,
#    'lng': -38.625625,
#    'alt': 5567,
#    'dir': 260.4,
#    'speed': 574,
#    'v_speed': 0,
#    'flight_number': '6401',
#    'flight_icao': 'AZU6401',
#    'flight_iata': 'AD6401',
#    'dep_icao': 'SBSV',
#    'dep_iata': 'SSA',
#    'arr_icao': 'SBSP',
#    'arr_iata': 'CGH',
#    'airline_icao': 'AZU',
#    'airline_iata': 'AD',
#    'aircraft_icao': 'E295',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '00B22B',
#    'reg_number': 'ZS-SZI',
#    'flag': 'ZA',
#    'lat': -33.5523,
#    'lng': 19.585,
#    'alt': 7129,
#    'dir': 52.9,
#    'speed': 899,
#    'v_speed': 0,
#    'flight_number': '362',
#    'flight_icao': 'SAA362',
#    'flight_iata': 'SA362',
#    'dep_icao': 'FACT',
#    'dep_iata': 'CPT',
#    'arr_icao': 'FAOR',
#    'arr_iata': 'JNB',
#    'airline_icao': 'SAA',
#    'airline_iata': 'SA',
#    'aircraft_icao': 'A320',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '06A2EB',
#    'reg_number': 'A7-BHH',
#    'flag': 'QA',
#    'lat': 23.188634,
#    'lng': 76.505154,
#    'alt': 11602,
#    'dir': 270.6,
#    'speed': 755,
#    'v_speed': 0,
#    'flight_number': '977',
#    'flight_icao': 'QTR977',
#    'flight_iata': 'QR977',
#    'dep_icao': 'VVNB',
#    'dep_iata': 'HAN',
#    'arr_icao': 'OTHH',
#    'arr_iata': 'DOH',
#    'airline_icao': 'QTR',
#    'airline_iata': 'QR',
#    'aircraft_icao': 'B789',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '80161A',
#    'reg_number': 'VT-IQK',
#    'flag': 'IN',
#    'lat': 11.046328,
#    'lng': 77.927594,
#    'alt': 10611,
#    'dir': 234.2,
#    'speed': 840,
#    'v_speed': 0,
#    'flight_number': '597',
#    'flight_icao': 'IGO597',
#    'flight_iata': '6E597',
#    'dep_icao': 'VOMM',
#    'dep_iata': 'MAA',
#    'arr_icao': 'VOCI',
#    'arr_iata': 'COK',
#    'airline_icao': 'IGO',
#    'airline_iata': '6E',
#    'aircraft_icao': 'A20N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '80152E',
#    'reg_number': 'VT-IPG',
#    'flag': 'IN',
#    'lat': 15.136964,
#    'lng': 78.343071,
#    'alt': 11937,
#    'dir': 189.9,
#    'speed': 798,
#    'v_speed': 0,
#    'squawk': '1000',
#    'flight_number': '204',
#    'flight_icao': 'IGO204',
#    'flight_iata': '6E204',
#    'dep_icao': 'VOHS',
#    'dep_iata': 'HYD',
#    'arr_icao': 'VOCI',
#    'arr_iata': 'COK',
#    'airline_icao': 'IGO',
#    'airline_iata': '6E',
#    'aircraft_icao': 'A20N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '06A0DC',
#    'reg_number': 'A7-BAS',
#    'flag': 'QA',
#    'lat': 19.179531,
#    'lng': 78.513807,
#    'alt': 11587,
#    'dir': 284.6,
#    'speed': 821,
#    'v_speed': 0,
#    'flight_number': '933',
#    'flight_icao': 'QTR933',
#    'flight_iata': 'QR933',
#    'dep_icao': 'RPLL',
#    'dep_iata': 'MNL',
#    'arr_icao': 'OTHH',
#    'arr_iata': 'DOH',
#    'airline_icao': 'QTR',
#    'airline_iata': 'QR',
#    'aircraft_icao': 'B77W',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '80141F',
#    'reg_number': 'VT-ILH',
#    'flag': 'IN',
#    'lat': 17.303955,
#    'lng': 78.533969,
#    'alt': 1998,
#    'dir': 333.5,
#    'speed': 520,
#    'v_speed': 0,
#    'flight_number': '1233',
#    'flight_icao': 'IGO1233',
#    'flight_iata': '6E1233',
#    'dep_icao': 'VOHS',
#    'dep_iata': 'HYD',
#    'arr_icao': 'OKKK',
#    'arr_iata': 'KWI',
#    'airline_icao': 'IGO',
#    'airline_iata': '6E',
#    'aircraft_icao': 'A21N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '06A110',
#    'reg_number': 'A7-AOB',
#    'flag': 'QA',
#    'lat': 13.119848,
#    'lng': 80.254881,
#    'alt': 12250,
#    'dir': 298.2,
#    'speed': 911,
#    'v_speed': 0,
#    'flight_number': '963',
#    'flight_icao': 'QTR963',
#    'flight_iata': 'QR963',
#    'dep_icao': 'WADD',
#    'dep_iata': 'DPS',
#    'arr_icao': 'OTHH',
#    'arr_iata': 'DOH',
#    'airline_icao': 'QTR',
#    'airline_iata': 'QR',
#    'aircraft_icao': 'A35K',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '8013CF',
#    'reg_number': 'VT-IUV',
#    'flag': 'IN',
#    'lat': 14.525435,
#    'lng': 81.654157,
#    'alt': 9072,
#    'dir': 45.8,
#    'speed': 866,
#    'v_speed': 0,
#    'squawk': '1000',
#    'flight_number': '923',
#    'flight_icao': 'IGO923',
#    'flight_iata': '6E923',
#    'dep_icao': 'VOMM',
#    'dep_iata': 'MAA',
#    'arr_icao': 'VECC',
#    'arr_iata': 'CCU',
#    'airline_icao': 'IGO',
#    'airline_iata': '6E',
#    'aircraft_icao': 'A21N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '75054C',
#    'reg_number': '9M-MAH',
#    'flag': 'MY',
#    'lat': 12.393632,
#    'lng': 81.760465,
#    'alt': 12852,
#    'dir': 298.3,
#    'speed': 933,
#    'v_speed': 0,
#    'flight_number': '160',
#    'flight_icao': 'MAS160',
#    'flight_iata': 'MH160',
#    'dep_icao': 'WMKK',
#    'dep_iata': 'KUL',
#    'arr_icao': 'OTHH',
#    'arr_iata': 'DOH',
#    'airline_icao': 'MAS',
#    'airline_iata': 'MH',
#    'aircraft_icao': 'A359',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '80154A',
#    'reg_number': 'VT-YAP',
#    'flag': 'IN',
#    'lat': 18.747664,
#    'lng': 84.228785,
#    'alt': 11617,
#    'dir': 233,
#    'speed': 772,
#    'v_speed': 0,
#    'flight_number': '1564',
#    'flight_icao': 'AKJ1564',
#    'flight_iata': 'QP1564',
#    'dep_icao': 'VECC',
#    'dep_iata': 'CCU',
#    'arr_icao': 'VOBL',
#    'arr_iata': 'BLR',
#    'airline_icao': 'AKJ',
#    'airline_iata': 'QP',
#    'aircraft_icao': 'B38M',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '8015A4',
#    'reg_number': 'VT-IPS',
#    'flag': 'IN',
#    'lat': 22.158513,
#    'lng': 85.443283,
#    'alt': 9986,
#    'dir': 80.6,
#    'speed': 965,
#    'v_speed': 0,
#    'flight_number': '7216',
#    'flight_icao': 'IGO7216',
#    'flight_iata': '6E7216',
#    'dep_icao': 'VARP',
#    'dep_iata': 'RPR',
#    'arr_icao': 'VECC',
#    'arr_iata': 'CCU',
#    'airline_icao': 'IGO',
#    'airline_iata': '6E',
#    'aircraft_icao': 'A20N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '717CE6',
#    'reg_number': 'HZ-NS44',
#    'flag': 'SA',
#    'lat': 23.27627,
#    'lng': 52.704749,
#    'alt': 10383,
#    'dir': 242,
#    'speed': 737,
#    'v_speed': 0,
#    'flight_number': '212',
#    'flight_icao': 'KNE212',
#    'flight_iata': 'XY212',
#    'dep_icao': 'OMDB',
#    'dep_iata': 'DXB',
#    'arr_icao': 'OERK',
#    'arr_iata': 'RUH',
#    'airline_icao': 'KNE',
#    'airline_iata': 'XY',
#    'aircraft_icao': 'A20N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '70606C',
#    'reg_number': '9K-AKR',
#    'flag': 'KW',
#    'lat': 25.032394,
#    'lng': 55.677279,
#    'alt': 10406,
#    'dir': 137.5,
#    'speed': 895,
#    'v_speed': 0,
#    'flight_number': '363',
#    'flight_icao': 'KAC363',
#    'flight_iata': 'KU363',
#    'dep_icao': 'OKKK',
#    'dep_iata': 'KWI',
#    'arr_icao': 'VCBI',
#    'arr_iata': 'CMB',
#    'airline_icao': 'KAC',
#    'airline_iata': 'KU',
#    'aircraft_icao': 'A20N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '73806B',
#    'reg_number': '4X-EKS',
#    'flag': 'IL',
#    'lat': 34.014656,
#    'lng': 31.383616,
#    'alt': 10992,
#    'dir': 324,
#    'speed': 718,
#    'v_speed': 0,
#    'flight_number': '351',
#    'flight_icao': 'ELY351',
#    'flight_iata': 'LY351',
#    'dep_icao': 'LLBG',
#    'dep_iata': 'TLV',
#    'arr_icao': 'EDDM',
#    'arr_iata': 'MUC',
#    'airline_icao': 'ELY',
#    'airline_iata': 'LY',
#    'aircraft_icao': 'B738',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '7609F1',
#    'reg_number': 'AP-BOQ',
#    'flag': 'PK',
#    'lat': 26.553743,
#    'lng': 49.885862,
#    'alt': 11297,
#    'dir': 240.6,
#    'speed': 749,
#    'v_speed': 0,
#    'flight_number': '586',
#    'flight_icao': 'FJL586',
#    'flight_iata': '9P586',
#    'dep_icao': 'OPLA',
#    'dep_iata': 'LHE',
#    'arr_icao': 'OEJN',
#    'arr_iata': 'JED',
#    'airline_icao': 'FJL',
#    'airline_iata': '9P',
#    'aircraft_icao': 'A320',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '4D22AC',
#    'reg_number': '9H-HLY',
#    'flag': 'GR',
#    'lat': 38.541863,
#    'lng': 18.839714,
#    'alt': 11267,
#    'dir': 108.8,
#    'speed': 978,
#    'v_speed': 0,
#    'flight_number': '251',
#    'flight_icao': 'BBG251',
#    'flight_iata': 'BZ251',
#    'dep_icao': 'LEBL',
#    'dep_iata': 'BCN',
#    'arr_icao': 'LLBG',
#    'arr_iata': 'TLV',
#    'airline_icao': 'BBG',
#    'airline_iata': 'BZ',
#    'aircraft_icao': 'B738',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '4CADC8',
#    'reg_number': 'EI-HJP',
#    'flag': 'IT',
#    'lat': 41.022974,
#    'lng': 21.469583,
#    'alt': 12432,
#    'dir': 271.8,
#    'speed': 785,
#    'v_speed': 0,
#    'flight_number': '759',
#    'flight_icao': 'ITY759',
#    'flight_iata': 'AZ759',
#    'dep_icao': 'VTBS',
#    'dep_iata': 'BKK',
#    'arr_icao': 'LIRF',
#    'arr_iata': 'FCO',
#    'airline_icao': 'ITY',
#    'airline_iata': 'AZ',
#    'aircraft_icao': 'A339',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '020142',
#    'reg_number': 'CN-COJ',
#    'flag': 'MA',
#    'lat': 31.397878,
#    'lng': -8.841528,
#    'alt': 5254,
#    'dir': 204.2,
#    'speed': 540,
#    'v_speed': 0,
#    'flight_number': '483',
#    'flight_icao': 'RAM483',
#    'flight_iata': 'AT483',
#    'dep_icao': 'GMMN',
#    'dep_iata': 'CMN',
#    'arr_icao': 'GMAD',
#    'arr_iata': 'AGA',
#    'airline_icao': 'RAM',
#    'airline_iata': 'AT',
#    'aircraft_icao': 'AT76',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '80073E',
#    'reg_number': 'VT-ANX',
#    'flag': 'IN',
#    'lat': 46.7804,
#    'lng': 18.585074,
#    'alt': 11251,
#    'dir': 295.7,
#    'speed': 982,
#    'v_speed': 0,
#    'flight_number': '159',
#    'flight_icao': 'AIC159',
#    'flight_iata': 'AI159',
#    'dep_icao': 'VAAH',
#    'dep_iata': 'AMD',
#    'arr_icao': 'EGKK',
#    'arr_iata': 'LGW',
#    'airline_icao': 'AIC',
#    'airline_iata': 'AI',
#    'aircraft_icao': 'B788',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '407FDA',
#    'reg_number': 'G-WUKX',
#    'flag': 'UK',
#    'lat': 42.730606,
#    'lng': 20.449784,
#    'alt': 9705,
#    'dir': 316.6,
#    'speed': 847,
#    'v_speed': 0,
#    'flight_number': '5304',
#    'flight_icao': 'WUK5304',
#    'flight_iata': 'W95304',
#    'dep_icao': 'OJAI',
#    'dep_iata': 'AMM',
#    'arr_icao': 'EGGW',
#    'arr_iata': 'LTN',
#    'airline_icao': 'WUK',
#    'airline_iata': 'W9',
#    'aircraft_icao': 'A21N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '4BC859',
#    'reg_number': 'TC-RBY',
#    'flag': 'TR',
#    'lat': 45.577464,
#    'lng': 21.862754,
#    'alt': 9598,
#    'dir': 138.2,
#    'speed': 795,
#    'v_speed': 0,
#    'flight_number': '1046',
#    'flight_icao': 'PGT1046',
#    'flight_iata': 'PC1046',
#    'dep_icao': 'EDDH',
#    'dep_iata': 'HAM',
#    'arr_icao': 'LTFJ',
#    'arr_iata': 'SAW',
#    'airline_icao': 'PGT',
#    'airline_iata': 'PC',
#    'aircraft_icao': 'A21N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '010244',
#    'reg_number': 'SU-GFT',
#    'flag': 'EG',
#    'lat': 36.274875,
#    'lng': 9.526156,
#    'alt': 10688,
#    'dir': 98.7,
#    'speed': 997,
#    'v_speed': 0,
#    'flight_number': '848',
#    'flight_icao': 'MSR848',
#    'flight_iata': 'MS848',
#    'dep_icao': 'GMMN',
#    'dep_iata': 'CMN',
#    'arr_icao': 'HECA',
#    'arr_iata': 'CAI',
#    'airline_icao': 'MSR',
#    'airline_iata': 'MS',
#    'aircraft_icao': 'A21N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '02A262',
#    'reg_number': 'TS-ITC',
#    'flag': 'TN',
#    'lat': 41.614165,
#    'lng': 12.612856,
#    'alt': 10383,
#    'dir': 17.4,
#    'speed': 838,
#    'v_speed': 0,
#    'flight_number': '642',
#    'flight_icao': 'TAR642',
#    'flight_iata': 'TU642',
#    'dep_icao': 'DTTA',
#    'dep_iata': 'TUN',
#    'arr_icao': 'LOWW',
#    'arr_iata': 'VIE',
#    'airline_icao': 'TAR',
#    'airline_iata': 'TU',
#    'aircraft_icao': 'A320',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '4BB061',
#    'reg_number': 'TC-LCA',
#    'flag': 'TR',
#    'lat': 36.144212,
#    'lng': 15.298211,
#    'alt': 10794,
#    'dir': 216.8,
#    'speed': 725,
#    'v_speed': 0,
#    'flight_number': '552',
#    'flight_icao': 'THY552',
#    'flight_iata': 'TK552',
#    'dep_icao': 'DFFD',
#    'dep_iata': 'OUA',
#    'arr_icao': 'GABS',
#    'arr_iata': 'BKO',
#    'airline_icao': 'THY',
#    'airline_iata': 'TK',
#    'aircraft_icao': 'B38M',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '4ACA89',
#    'reg_number': 'SE-RTI',
#    'flag': 'SE',
#    'lat': 52.138586,
#    'lng': 18.943227,
#    'alt': 10992,
#    'dir': 228.1,
#    'speed': 965,
#    'v_speed': 0,
#    'flight_number': '2940',
#    'flight_icao': 'NSZ2940',
#    'flight_iata': 'D82940',
#    'dep_icao': 'EFHK',
#    'dep_iata': 'HEL',
#    'arr_icao': 'LIME',
#    'arr_iata': 'BGY',
#    'airline_icao': 'NSZ',
#    'airline_iata': 'D8',
#    'aircraft_icao': 'B38M',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '010147',
#    'reg_number': 'SU-GEA',
#    'flag': 'EG',
#    'lat': 53.181456,
#    'lng': 22.842867,
#    'alt': 10992,
#    'dir': 199,
#    'speed': 987,
#    'v_speed': 0,
#    'flight_number': '730',
#    'flight_icao': 'MSR730',
#    'flight_iata': 'MS730',
#    'dep_icao': 'UUDD',
#    'dep_iata': 'DME',
#    'arr_icao': 'HECA',
#    'arr_iata': 'CAI',
#    'airline_icao': 'MSR',
#    'airline_iata': 'MS',
#    'aircraft_icao': 'B738',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '502D0F',
#    'reg_number': 'YL-AAS',
#    'flag': 'LV',
#    'lat': 56.655294,
#    'lng': 23.691254,
#    'alt': 4170,
#    'dir': 7,
#    'speed': 584,
#    'v_speed': 0,
#    'squawk': '1000',
#    'flight_number': '696',
#    'flight_icao': 'BTI696',
#    'flight_iata': 'BT696',
#    'dep_icao': 'LFMN',
#    'dep_iata': 'NCE',
#    'arr_icao': 'EVRA',
#    'arr_iata': 'RIX',
#    'airline_icao': 'BTI',
#    'airline_iata': 'BT',
#    'aircraft_icao': 'BCS3',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '48AF09',
#    'reg_number': 'SP-LVK',
#    'flag': 'PL',
#    'lat': 58.184972,
#    'lng': 23.794902,
#    'alt': 11907,
#    'dir': 187.5,
#    'speed': 953,
#    'v_speed': 0,
#    'flight_number': '478',
#    'flight_icao': 'LOT478',
#    'flight_iata': 'LO478',
#    'dep_icao': 'EFRO',
#    'dep_iata': 'RVN',
#    'arr_icao': 'EPWA',
#    'arr_iata': 'WAW',
#    'airline_icao': 'LOT',
#    'airline_iata': 'LO',
#    'aircraft_icao': 'B38M',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '502D7D',
#    'reg_number': 'YL-ABS',
#    'flag': 'LV',
#    'lat': 56.474554,
#    'lng': 23.997346,
#    'alt': 5193,
#    'dir': 13.7,
#    'speed': 522,
#    'v_speed': 0,
#    'flight_number': '612',
#    'flight_icao': 'BTI612',
#    'flight_iata': 'BT612',
#    'dep_icao': 'LGAV',
#    'dep_iata': 'ATH',
#    'arr_icao': 'EVRA',
#    'arr_iata': 'RIX',
#    'airline_icao': 'BTI',
#    'airline_iata': 'BT',
#    'aircraft_icao': 'BCS3',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '8964AF',
#    'reg_number': 'A6-EVA',
#    'flag': 'AE',
#    'lat': 48.039962,
#    'lng': 15.491418,
#    'alt': 11503,
#    'dir': 294.1,
#    'speed': 956,
#    'v_speed': 0,
#    'flight_number': '19',
#    'flight_icao': 'UAE19',
#    'flight_iata': 'EK19',
#    'dep_icao': 'OMDB',
#    'dep_iata': 'DXB',
#    'arr_icao': 'EGCC',
#    'arr_iata': 'MAN',
#    'airline_icao': 'UAE',
#    'airline_iata': 'EK',
#    'aircraft_icao': 'A388',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '4CA98A',
#    'reg_number': 'EI-IMN',
#    'flag': 'IT',
#    'lat': 46.801837,
#    'lng': 7.807018,
#    'alt': 9369,
#    'dir': 140.3,
#    'speed': 820,
#    'v_speed': 0,
#    'squawk': '1000',
#    'flight_number': '313',
#    'flight_icao': 'ITY313',
#    'flight_iata': 'AZ313',
#    'dep_icao': 'LFPG',
#    'dep_iata': 'CDG',
#    'arr_icao': 'LIML',
#    'arr_iata': 'LIN',
#    'airline_icao': 'ITY',
#    'airline_iata': 'AZ',
#    'aircraft_icao': 'A319',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '4ACAA4',
#    'reg_number': 'SE-RUD',
#    'flag': 'SE',
#    'lat': 56.1062,
#    'lng': 7.847186,
#    'alt': 11747,
#    'dir': 202,
#    'speed': 845,
#    'v_speed': 0,
#    'flight_number': '827',
#    'flight_icao': 'SAS827',
#    'flight_iata': 'SK827',
#    'dep_icao': 'ENGM',
#    'dep_iata': 'OSL',
#    'arr_icao': 'EHAM',
#    'arr_iata': 'AMS',
#    'airline_icao': 'SAS',
#    'airline_iata': 'SK',
#    'aircraft_icao': 'A20N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '3474DA',
#    'reg_number': 'EC-OAS',
#    'flag': 'ES',
#    'lat': 39.161341,
#    'lng': 0.367038,
#    'alt': 10268,
#    'dir': 112,
#    'speed': 855,
#    'v_speed': 0,
#    'flight_number': '1903',
#    'flight_icao': 'IBE1903',
#    'flight_iata': 'IB1903',
#    'dep_icao': 'LEMD',
#    'dep_iata': 'MAD',
#    'arr_icao': 'HECA',
#    'arr_iata': 'CAI',
#    'airline_icao': 'IBS',
#    'airline_iata': 'I2',
#    'aircraft_icao': 'A21N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '3985A1',
#    'reg_number': 'F-HBNB',
#    'flag': 'FR',
#    'lat': 47.403081,
#    'lng': 3.973696,
#    'alt': 9118,
#    'dir': 328.4,
#    'speed': 817,
#    'v_speed': 0,
#    'squawk': '1000',
#    'flight_number': '6225',
#    'flight_icao': 'AFR6225',
#    'flight_iata': 'AF6225',
#    'dep_icao': 'LFMN',
# ...
#    'dir': 142,
#    'speed': 863,
#    'v_speed': 0,
#    'flight_number': '726',
#    'flight_icao': 'MSR726',
#    'flight_iata': 'MS726',
#    'dep_icao': 'EBBR',
#    'dep_iata': 'BRU',
#    'arr_icao': 'HECA',
#    'arr_iata': 'CAI',
#    'airline_icao': 'MSR',
#    'airline_iata': 'MS',
#    'aircraft_icao': 'B738',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '3965A6',
#    'reg_number': 'F-GZNG',
#    'flag': 'FR',
#    'lat': 42.981893,
#    'lng': 19.906567,
#    'alt': 10992,
#    'dir': 298,
#    'speed': 863,
#    'v_speed': 0,
#    'flight_number': '647',
#    'flight_icao': 'AFR647',
#    'flight_iata': 'AF647',
#    'dep_icao': 'FMEE',
#    'dep_iata': 'RUN',
#    'arr_icao': 'LFPG',
#    'arr_iata': 'CDG',
#    'airline_icao': 'AFR',
#    'airline_iata': 'AF',
#    'aircraft_icao': 'B77W',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '89617C',
#    'reg_number': 'A6-EGD',
#    'flag': 'AE',
#    'lat': 43.265221,
#    'lng': 20.267375,
#    'alt': 12212,
#    'dir': 267,
#    'speed': 850,
#    'v_speed': 0,
#    'flight_number': '95',
#    'flight_icao': 'UAE95',
#    'flight_iata': 'EK95',
#    'dep_icao': 'OMDB',
#    'dep_iata': 'DXB',
#    'arr_icao': 'LIRF',
#    'arr_iata': 'FCO',
#    'airline_icao': 'UAE',
#    'airline_iata': 'EK',
#    'aircraft_icao': 'B77W',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '3C4AD7',
#    'reg_number': 'D-ABVW',
#    'flag': 'DE',
#    'lat': 47.134137,
#    'lng': 20.663676,
#    'alt': 9468,
#    'dir': 119,
#    'speed': 863,
#    'v_speed': 0,
#    'flight_number': '728',
#    'flight_icao': 'DLH728',
#    'flight_iata': 'LH728',
#    'dep_icao': 'EDDF',
#    'dep_iata': 'FRA',
#    'arr_icao': 'ZSPD',
#    'arr_iata': 'PVG',
#    'airline_icao': 'DLH',
#    'airline_iata': 'LH',
#    'aircraft_icao': 'B744',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '3C670B',
#    'reg_number': 'D-AIXK',
#    'flag': 'DE',
#    'lat': 46.617543,
#    'lng': 20.771354,
#    'alt': 12212,
#    'dir': 292,
#    'speed': 931,
#    'v_speed': 0,
#    'flight_number': '713',
#    'flight_icao': 'DLH713',
#    'flight_iata': 'LH713',
#    'dep_icao': 'RKSI',
#    'dep_iata': 'ICN',
#    'arr_icao': 'EDDF',
#    'arr_iata': 'FRA',
#    'airline_icao': 'DLH',
#    'airline_iata': 'LH',
#    'aircraft_icao': 'A359',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '4843F2',
#    'reg_number': 'PH-BQO',
#    'flag': 'NL',
#    'lat': 42.090116,
#    'lng': 21.10111,
#    'alt': 10688,
#    'dir': 125.6,
#    'speed': 929,
#    'v_speed': 0,
#    'flight_number': '427',
#    'flight_icao': 'KLM427',
#    'flight_iata': 'KL427',
#    'dep_icao': 'EHAM',
#    'dep_iata': 'AMS',
#    'arr_icao': 'OMDB',
#    'arr_iata': 'DXB',
#    'airline_icao': 'KLM',
#    'airline_iata': 'KL',
#    'aircraft_icao': 'B772',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '48418C',
#    'reg_number': 'PH-BXR',
#    'flag': 'NL',
#    'lat': 44.689983,
#    'lng': 21.198566,
#    'alt': 12212,
#    'dir': 310,
#    'speed': 844,
#    'v_speed': 0,
#    'flight_number': '1960',
#    'flight_icao': 'KLM1960',
#    'flight_iata': 'KL1960',
#    'dep_icao': 'LTFM',
#    'dep_iata': 'IST',
#    'arr_icao': 'EHAM',
#    'arr_iata': 'AMS',
#    'airline_icao': 'KLM',
#    'airline_iata': 'KL',
#    'aircraft_icao': 'B739',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '3C6701',
#    'reg_number': 'D-AIXA',
#    'flag': 'DE',
#    'lat': 46.183177,
#    'lng': 21.360477,
#    'alt': 10924,
#    'dir': 115.3,
#    'speed': 833,
#    'v_speed': 0,
#    'flight_number': '718',
#    'flight_icao': 'DLH718',
#    'flight_iata': 'LH718',
#    'dep_icao': 'EDDM',
#    'dep_iata': 'MUC',
#    'arr_icao': 'RKSI',
#    'arr_iata': 'ICN',
#    'airline_icao': 'DLH',
#    'airline_iata': 'LH',
#    'aircraft_icao': 'A359',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '70C105',
#    'reg_number': 'A4O-SI',
#    'flag': 'OM',
#    'lat': 45.792994,
#    'lng': 21.974305,
#    'alt': 11244,
#    'dir': 299.6,
#    'speed': 977,
#    'v_speed': 0,
#    'flight_number': '131',
#    'flight_icao': 'OMA131',
#    'flight_iata': 'WY131',
#    'dep_icao': 'OOMS',
#    'dep_iata': 'MCT',
#    'arr_icao': 'LFPG',
#    'arr_iata': 'CDG',
#    'airline_icao': 'OMA',
#    'airline_iata': 'WY',
#    'aircraft_icao': 'B789',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '4C8085',
#    'reg_number': '5B-DDK',
#    'flag': 'CY',
#    'lat': 42.51806,
#    'lng': 22.113105,
#    'alt': 10078,
#    'dir': 156.5,
#    'speed': 771,
#    'v_speed': 0,
#    'flight_number': '461',
#    'flight_icao': 'CYF461',
#    'flight_iata': 'U8461',
#    'dep_icao': 'LKPR',
#    'dep_iata': 'PRG',
#    'arr_icao': 'LLBG',
#    'arr_iata': 'TLV',
#    'airline_icao': 'CYF',
#    'airline_iata': 'U8',
#    'aircraft_icao': 'A320',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '8963E6',
#    'reg_number': 'A6-EOI',
#    'flag': 'AE',
#    'lat': 44.880565,
#    'lng': 22.322534,
#    'alt': 11785,
#    'dir': 112,
#    'speed': 874,
#    'v_speed': 0,
#    'flight_number': '2',
#    'flight_icao': 'UAE2',
#    'flight_iata': 'EK2',
#    'dep_icao': 'EGLL',
#    'dep_iata': 'LHR',
#    'arr_icao': 'OMDB',
#    'arr_iata': 'DXB',
#    'airline_icao': 'UAE',
#    'airline_iata': 'EK',
#    'aircraft_icao': 'A388',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '3C65C2',
#    'reg_number': 'D-AINB',
#    'flag': 'DE',
#    'lat': 42.793616,
#    'lng': 22.547853,
#    'alt': 11602,
#    'dir': 323,
#    'speed': 804,
#    'v_speed': 0,
#    'flight_number': '1293',
#    'flight_icao': 'DLH1293',
#    'flight_iata': 'LH1293',
#    'dep_icao': 'LCLK',
#    'dep_iata': 'LCA',
#    'arr_icao': 'EDDF',
#    'arr_iata': 'FRA',
#    'airline_icao': 'DLH',
#    'airline_iata': 'LH',
#    'aircraft_icao': 'A20N',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '4A08A5',
#    'reg_number': 'YR-BEE',
#    'flag': 'MD',
#    'lat': 46.382511,
#    'lng': 22.853569,
#    'alt': 8234,
#    'dir': 135,
#    'speed': 857,
#    'v_speed': 0,
#    'squawk': '1000',
#    'flight_number': '763',
#    'flight_icao': 'HYS763',
#    'flight_iata': 'H4763',
#    'dep_icao': 'LROD',
#    'dep_iata': 'OMR',
#    'arr_icao': 'LROP',
#    'arr_iata': 'OTP',
#    'airline_icao': 'HYS',
#    'airline_iata': 'H4',
#    'aircraft_icao': 'A320',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '39A2E0',
#    'reg_number': 'F-HIXA',
#    'flag': 'DZ',
#    'lat': 38.925058,
#    'lng': 6.169508,
#    'alt': 11221,
#    'dir': 226,
#    'speed': 751,
#    'v_speed': 0,
#    'flight_number': '3017',
#    'flight_icao': 'DAH3017',
#    'flight_iata': 'AH3017',
#    'dep_icao': 'LTFM',
#    'dep_iata': 'IST',
#    'arr_icao': 'DAAG',
#    'arr_iata': 'ALG',
#    'airline_icao': 'DAH',
#    'airline_iata': 'AH',
#    'aircraft_icao': 'B738',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '3C66E6',
#    'reg_number': 'D-AIWF',
#    'flag': 'DE',
#    'lat': 40.116053,
#    'lng': 6.901444,
#    'alt': 10908,
#    'dir': 27,
#    'speed': 871,
#    'v_speed': 0,
#    'squawk': '1000',
#    'flight_number': '313',
#    'flight_icao': 'OCN313',
#    'flight_iata': '4Y313',
#    'dep_icao': 'GCTS',
#    'dep_iata': 'TFS',
#    'arr_icao': 'EDDM',
#    'arr_iata': 'MUC',
#    'airline_icao': 'OCN',
#    'airline_iata': '4Y',
#    'aircraft_icao': 'A320',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '02A1A6',
#    'reg_number': 'TS-ING',
#    'flag': 'TN',
#    'lat': 38.485555,
#    'lng': 8.321574,
#    'alt': 11587,
#    'dir': 340,
#    'speed': 815,
#    'v_speed': 0,
#    'flight_number': '574',
#    'flight_icao': 'LBT574',
#    'flight_iata': 'BJ574',
#    'dep_icao': 'DTTJ',
#    'dep_iata': 'DJE',
#    'arr_icao': 'LFLL',
#    'arr_iata': 'LYS',
#    'airline_icao': 'LBT',
#    'airline_iata': 'BJ',
#    'aircraft_icao': 'A320',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '02A192',
#    'reg_number': 'TS-IMS',
#    'flag': 'TN',
#    'lat': 40.099091,
#    'lng': 8.805579,
#    'alt': 11213,
#    'dir': 158.2,
#    'speed': 839,
#    'v_speed': 0,
#    'flight_number': '251',
#    'flight_icao': 'TAR251',
#    'flight_iata': 'TU251',
#    'dep_icao': 'LFMN',
#    'dep_iata': 'NCE',
#    'arr_icao': 'DTMB',
#    'arr_iata': 'MIR',
#    'airline_icao': 'TAR',
#    'airline_iata': 'TU',
#    'aircraft_icao': 'A320',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '02A1A4',
#    'reg_number': 'TS-INE',
#    'flag': 'TN',
#    'lat': 41.226863,
#    'lng': 8.841402,
#    'alt': 10916,
#    'dir': 337.1,
#    'speed': 834,
#    'v_speed': 0,
#    'squawk': '1000',
#    'flight_number': '520',
#    'flight_icao': 'LBT520',
#    'flight_iata': 'BJ520',
#    'dep_icao': 'DTTA',
#    'dep_iata': 'TUN',
#    'arr_icao': 'LFPG',
#    'arr_iata': 'CDG',
#    'airline_icao': 'LBT',
#    'airline_iata': 'BJ',
#    'aircraft_icao': 'A320',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '4A09B2',
#    'reg_number': 'YR-BMR',
#    'flag': 'IT',
#    'lat': 40.110243,
#    'lng': 9.109125,
#    'alt': 9087,
#    'dir': 350.4,
#    'speed': 795,
#    'v_speed': 0,
#    'flight_number': '2360',
#    'flight_icao': 'AEZ2360',
#    'flight_iata': 'XZ2360',
#    'dep_icao': 'LIEE',
#    'dep_iata': 'CAG',
#    'arr_icao': 'LIML',
#    'arr_iata': 'LIN',
#    'airline_icao': 'AEZ',
#    'airline_iata': 'XZ',
#    'aircraft_icao': 'B737',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '717CA8',
#    'reg_number': 'HZ-NE24',
#    'flag': 'SA',
#    'lat': 36.206362,
#    'lng': 10.105918,
#    'alt': 11061,
#    'dir': 280,
#    'speed': 726,
#    'v_speed': 0,
#    'flight_number': '663',
#    'flight_icao': 'KNE663',
#    'flight_iata': 'XY663',
#    'dep_icao': 'OEJN',
#    'dep_iata': 'JED',
#    'arr_icao': 'GMMN',
#    'arr_iata': 'CMN',
#    'airline_icao': 'KNE',
#    'airline_iata': 'XY',
#    'aircraft_icao': 'A333',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '02A263',
#    'reg_number': 'TS-ITD',
#    'flag': 'TN',
#    'lat': 37.562673,
#    'lng': 10.177992,
#    'alt': 3606,
#    'dir': 170.7,
#    'speed': 716,
#    'v_speed': 0,
#    'flight_number': '793',
#    'flight_icao': 'TAR793',
#    'flight_iata': 'TU793',
#    'dep_icao': 'EGKK',
#    'dep_iata': 'LGW',
#    'arr_icao': 'DTTA',
#    'arr_iata': 'TUN',
#    'airline_icao': 'TAR',
#    'airline_iata': 'TU',
#    'aircraft_icao': 'A320',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '4CAAA7',
#    'reg_number': 'EI-IMV',
#    'flag': 'IT',
#    'lat': 40.539787,
#    'lng': 11.810974,
#    'alt': 9636,
#    'dir': 192,
#    'speed': 788,
#    'v_speed': 0,
#    'flight_number': '866',
#    'flight_icao': 'ITY866',
#    'flight_iata': 'AZ866',
#    'dep_icao': 'LIRF',
#    'dep_iata': 'FCO',
#    'arr_icao': 'DTTA',
#    'arr_iata': 'TUN',
#    'airline_icao': 'ITY',
#    'airline_iata': 'AZ',
#    'aircraft_icao': 'A319',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '020121',
#    'reg_number': 'CN-RGS',
#    'flag': 'MA',
#    'lat': 37.469833,
#    'lng': 12.760983,
#    'alt': 12212,
#    'dir': 303,
#    'speed': 790,
#    'v_speed': 0,
#    'flight_number': '249',
#    'flight_icao': 'RAM249',
#    'flight_iata': 'AT249',
#    'dep_icao': 'OEJN',
#    'dep_iata': 'JED',
#    'arr_icao': 'GMMN',
#    'arr_iata': 'CMN',
#    'airline_icao': 'RAM',
#    'airline_iata': 'AT',
#    'aircraft_icao': 'B788',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '7105AD',
#    'reg_number': 'HZ-AR26',
#    'flag': 'SA',
#    'lat': 36.398287,
#    'lng': 12.926706,
#    'alt': 11297,
#    'dir': 100.2,
#    'speed': 1063,
#    'v_speed': 0,
#    'flight_number': '220',
#    'flight_icao': 'SVA220',
#    'flight_iata': 'SV220',
#    'dep_icao': 'LEMD',
#    'dep_iata': 'MAD',
#    'arr_icao': 'OEJN',
#    'arr_iata': 'JED',
#    'airline_icao': 'SVA',
#    'airline_iata': 'SV',
#    'aircraft_icao': 'B78X',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '8963D3',
#    'reg_number': 'A6-EPD',
#    'flag': 'AE',
#    'lat': 36.279683,
#    'lng': 13.577622,
#    'alt': 10688,
#    'dir': 100.3,
#    'speed': 1033,
#    'v_speed': 0,
#    'flight_number': '192',
#    'flight_icao': 'UAE192',
#    'flight_iata': 'EK192',
#    'dep_icao': 'LPPT',
#    'dep_iata': 'LIS',
#    'arr_icao': 'OMDB',
#    'arr_iata': 'DXB',
#    'airline_icao': 'UAE',
#    'airline_iata': 'EK',
#    'aircraft_icao': 'B77W',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '7100B4',
#    'reg_number': 'HZ-ARB',
#    'flag': 'SA',
#    'lat': 39.952498,
#    'lng': 14.345381,
#    'alt': 11846,
#    'dir': 129,
#    'speed': 962,
#    'v_speed': 0,
#    'flight_number': '250',
#    'flight_icao': 'SVA250',
#    'flight_iata': 'SV250',
#    'dep_icao': 'EGBB',
#    'dep_iata': 'BHX',
#    'arr_icao': 'OEJN',
#    'arr_iata': 'JED',
#    'airline_icao': 'SVA',
#    'airline_iata': 'SV',
#    'aircraft_icao': 'B789',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '7103D6',
#    'reg_number': 'HZ-AR12',
#    'flag': 'SA',
#    'lat': 39.702875,
#    'lng': 14.763498,
#    'alt': 11907,
#    'dir': 129.1,
#    'speed': 987,
#    'v_speed': 0,
#    'flight_number': '100',
#    'flight_icao': 'SVA100',
#    'flight_iata': 'SV100',
#    'dep_icao': 'EGKK',
#    'dep_iata': 'LGW',
#    'arr_icao': 'OEJN',
#    'arr_iata': 'JED',
#    'airline_icao': 'SVA',
#    'airline_iata': 'SV',
#    'aircraft_icao': 'B789',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '4007F3',
#    'reg_number': 'G-YMMH',
#    'flag': 'UK',
#    'lat': 41.061486,
#    'lng': 16.565348,
#    'alt': 10688,
#    'dir': 118.5,
#    'speed': 918,
#    'v_speed': 0,
#    'flight_number': '119',
#    'flight_icao': 'BAW119',
#    'flight_iata': 'BA119',
#    'dep_icao': 'EGLL',
#    'dep_iata': 'LHR',
#    'arr_icao': 'VOBL',
#    'arr_iata': 'BLR',
#    'airline_icao': 'BAW',
#    'airline_iata': 'BA',
#    'aircraft_icao': 'B772',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': '4BB064',
#    'reg_number': 'TC-LCD',
#    'flag': 'TR',
#    'lat': 37.812528,
#    'lng': 17.532615,
#    'alt': 10383,
#    'dir': 231,
#    'speed': 674,
#    'v_speed': 0,
#    'flight_number': '533',
#    'flight_icao': 'THY533',
#    'flight_iata': 'TK533',
#    'dep_icao': 'DFFD',
#    'dep_iata': 'OUA',
#    'arr_icao': 'GFLL',
#    'arr_iata': 'FNA',
#    'airline_icao': 'THY',
#    'airline_iata': 'TK',
#    'aircraft_icao': 'B38M',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'AA4440',
#    'reg_number': 'N76021',
#    'flag': 'US',
#    'lat': 61.177108,
#    'lng': -169.285407,
#    'alt': 11297,
#    'dir': 64.2,
#    'speed': 1000,
#    'v_speed': 0,
#    'flight_number': '130',
#    'flight_icao': 'UAL130',
#    'flight_iata': 'UA130',
#    'dep_icao': 'RJTT',
#    'dep_iata': 'HND',
#    'arr_icao': 'KEWR',
#    'arr_iata': 'EWR',
#    'airline_icao': 'UAL',
#    'airline_iata': 'UA',
#    'aircraft_icao': 'B772',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'A60B1E',
#    'reg_number': 'N489MC',
#    'flag': 'US',
#    'lat': 60.398466,
#    'lng': -167.54578,
#    'alt': 10992,
#    'dir': 251.1,
#    'speed': 746,
#    'v_speed': 0,
#    'flight_number': '8192',
#    'flight_icao': 'GTI8192',
#    'flight_iata': '5Y8192',
#    'dep_icao': 'PANC',
#    'dep_iata': 'ANC',
#    'arr_icao': 'RKSI',
#    'arr_iata': 'ICN',
#    'airline_icao': 'GTI',
#    'airline_iata': '5Y',
#    'aircraft_icao': 'B744',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   {'hex': 'C0173E',
#    'reg_number': 'C-FIUV',
#    'flag': 'CA',
#    'lat': 58.06352,
#    'lng': -165.03652,
#    'alt': 10688,
#    'dir': 86,
#    'speed': 971,
#    'v_speed': 0,
#    'flight_number': '4',
#    'flight_icao': 'ACA4',
#    'flight_iata': 'AC4',
#    'dep_icao': 'RJAA',
#    'dep_iata': 'NRT',
#    'arr_icao': 'CYVR',
#    'arr_iata': 'YVR',
#    'airline_icao': 'ACA',
#    'airline_iata': 'AC',
#    'aircraft_icao': 'B77W',
#    'updated': 1766679581,
#    'status': 'en-route',
#    'type': 'adsb'},
#   ...],
#  'terms': "Unauthorized access is prohibited and punishable by law. \nReselling data 'As Is' without AirLabs.Co permission is strictly prohibited. \nFull terms on https://airlabs.co/. \nContact us info@airlabs.co"}
